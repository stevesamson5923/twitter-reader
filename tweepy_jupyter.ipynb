# %%
import tweepy
from tweepy import OAuthHandler
import webbrowser
import time
def authenticate():
    consumer_key = 'H5Jla4zoZcNLtDiuR125fgPhR'
    consumer_secret = 'HWSbxGzQYgEhwOigJCrggYWzuGRKNcBX93CPXiyxi9RYYVrBhc'
    callback_uri = 'oob'
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    redirect_url = auth.get_authorization_url() 
    #webbrowser.open(redirect_url)
    #print(redirect_url)
    access_token = '493298328-xZkQxyCSr5QkHN8VbGwBaY2SAZNyyH3X3yFrmr6N'
    access_secret_token = '3cPqkMk12ixa6GAfSly6W6KwuYdK0Uapw2KDZVEmP0wSI'
    auth.set_access_token(access_token,access_secret_token)
    api = tweepy.API(auth)
    #me = api.me()
    return api

# %%
me = authenticate()
me.followers_ids
# Out:
# <function tweepy.binder.bind_api.<locals>._call(*args, **kwargs)>

# %%
dir(me)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'contributors_enabled',
#  'created_at',
#  'default_profile',
#  'default_profile_image',
#  'description',
#  'entities',
#  'favourites_count',
#  'follow',
#  'follow_request_sent',
#  'followers',
#  'followers_count',
#  'followers_ids',
#  'following',
#  'friends',
#  'friends_count',
#  'geo_enabled',
#  'has_extended_profile',
#  'id',
#  'id_str',
#  'is_translation_enabled',
#  'is_translator',
#  'lang',
#  'listed_count',
#  'lists',
#  'lists_memberships',
#  'lists_subscriptions',
#  'location',
#  'name',
#  'needs_phone_verification',
#  'notifications',
#  'parse',
#  'parse_list',
#  'profile_background_color',
#  'profile_background_image_url',
#  'profile_background_image_url_https',
#  'profile_background_tile',
#  'profile_image_url',
#  'profile_image_url_https',
#  'profile_link_color',
#  'profile_location',
#  'profile_sidebar_border_color',
#  'profile_sidebar_fill_color',
#  'profile_text_color',
#  'profile_use_background_image',
#  'protected',
#  'screen_name',
#  'status',
#  'statuses_count',
#  'suspended',
#  'time_zone',
#  'timeline',
#  'translator_type',
#  'unfollow',
#  'url',
#  'utc_offset',
#  'verified']

# %%
from tkinter import *

root = Tk()
scrollbar = Scrollbar(root)
scrollbar.pack( side = RIGHT, fill = Y )

mylist = Listbox(root, yscrollcommand = scrollbar.set )
for line in range(100):
    mylist.insert(END, "This is line number " + str(line))

mylist.pack( side = LEFT, fill = BOTH )
scrollbar.config( command = mylist.yview )

mainloop()

# %%
#auth.get_access_token(user_pin)
#print(auth.access_token, auth.access_token_secret)

# %%
from tkinter import *
from PIL import ImageTk, Image
import PIL 
import urllib.request
from datetime import datetime

root = Tk()
root.title('Charts')
root.geometry('1000x600')
root.resizable(0,0)
#root.tk.call('encoding', 'system', 'unicode')
hover_bg = '#613504'
leave_bg = '#fca503'

leftframe = Frame(root,width=150,bg='#fca503')
leftframe.pack(side=LEFT,expand=0,fill=BOTH)
rightframe = Frame(root,width=550,bg=hover_bg)
rightframe.pack(side=LEFT,expand=1,fill=BOTH)

me=None
api=None
if me:
    #print(me.screen_name)
    pass
else:
    api = authenticate()
    me = api.me()

flag_pressed_follow = False
flag_pressed_read = False
#print('Welcome'+me.screen_name)

def unpack_others():
    for a in rightframe.winfo_children():
        a.destroy() 

def hover(id):
    if id == 1:
        following.configure(bg=hover_bg)
    elif id == 2:
        Read_tweet.configure(bg=hover_bg)
    elif id == 3:
        search_tweet.configure(bg=hover_bg)
    
def leave(id):
    if id == 1 and not flag_pressed_follow:
        following.configure(bg=leave_bg)
    elif id == 2 and not flag_pressed_read:
        Read_tweet.configure(bg=leave_bg)
    elif id == 3:
        search_tweet.configure(bg=leave_bg)

def download_image(URL,count):
    with urllib.request.urlopen(URL) as url:
        with open('friend_photo_'+str(count)+'.jpg', 'wb') as f:
            f.write(url.read())

def download_image_read_tweets(URL,count):
    with urllib.request.urlopen(URL) as url:
        with open('tweet_photo_'+str(count)+'.jpg', 'wb') as f:
            f.write(url.read())

def download_user_image(URL):
    with urllib.request.urlopen(URL) as url:
        with open('profile_photo.jpg', 'wb') as f:
            f.write(url.read())

def display_following():
    global friend_frame
    count=1
    friend_frame = Frame(rightframe,bg=hover_bg,width=550,height=450)  
    friend_frame.pack(side='top',expand=1,fill='both')
    for index,friend in enumerate(me.friends()):
        #print(friend.screen_name)
        #print(friend.profile_image_url)
        download_image(friend.profile_image_url,count)
        
        friend_name = Label(rightframe,text=friend.screen_name,bg=hover_bg,fg='#fff')
        img = PIL.Image.open('friend_photo_'+str(count)+'.jpg')
        img = ImageTk.PhotoImage(img)
        #img = img.subsample(6,6)
        #profile_photo = Label(rightframe,text='Image',image=img)  
        canvas = Canvas(friend_frame,width=48,height=48,bg=hover_bg)
        canvas.image = img
        canvas.create_image(0,0,anchor='nw',image=img)
    
        canvas.grid(row=index,column=0,padx=20)
        
        username = Label(friend_frame,text=friend.screen_name,bg=hover_bg,fg='#fff',font=('Lucida Console',16))
        username.grid(row=index,column=1,padx=20,sticky='E')
        
        follow_unfollow_but(index,friend.screen_name)
        count = count + 1
            
def refresh_list():
    global friend_frame
    for a in friend_frame.winfo_children():
        a.destroy()
    friend_frame.destroy()
    display_following()
            
def follow_unfollow(friend_screen_name):
    #for friend in me.friends():
    #if friend.screen_name == friend_screen_name:
    api.destroy_friendship(friend_screen_name)
    refresh_list()
        
def change_but_text_on_enter(follow_but):
    follow_but.configure(text='Unfollow')
    follow_but.configure(bg=leave_bg)

def change_but_text_on_leave(follow_but):
    follow_but.configure(text='Following')
    follow_but.configure(bg=hover_bg)
    
def follow_unfollow_but(index, friend_screen_name):
    global friend_frame
    follow_but = Button(friend_frame,text='Following',font=('Helvetica',16),
                        bg=hover_bg,bd=2,fg='#fff',relief=GROOVE,command=lambda :follow_unfollow(friend_screen_name))
    follow_but.bind('<Enter>',lambda x: change_but_text_on_enter(follow_but))
    follow_but.bind('<Leave>',lambda x: change_but_text_on_leave(follow_but))
    follow_but.grid(row=index,column=2,padx=20)
    
        
def show_following():
    global flag_pressed_read
    global flag_pressed_follow
    flag_pressed_follow=True
    flag_pressed_read=False
    Read_tweet.configure(bg=leave_bg)
    following.configure(bg=hover_bg)
    
    unpack_others()
    
    api = authenticate()
    me = api.me()
    
    user_frame = Frame(rightframe,width=550,bg=hover_bg)    
    username = Label(user_frame,text='Welcome '+me.screen_name,bg=hover_bg,fg='#fff',font=('Chiller',20))
    
    URL=me.profile_image_url
    download_user_image(URL)
    
    #photo1 = PhotoImage(file = 'profile_photo.jpg')
    #photoimage1 = photo1.subsample(1, 1)
    img = PIL.Image.open('profile_photo.jpg')
    img = ImageTk.PhotoImage(img)
    #img = img.subsample(6,6)
    #profile_photo = Label(rightframe,text='Image',image=img)  
    canvas = Canvas(user_frame,width=48,height=48,bg=hover_bg)
    canvas.image = img
    canvas.create_image(0,0,anchor='nw',image=img)
    
    #profile_photo.configure(image=photoimage1)
    #profile_photo.grid(row=0,column=0)
    user_frame.pack(side='top',expand=0,fill='x')
    canvas.pack(side='right',anchor='ne',padx=(5,15),pady=15)
    username.pack(side='right',anchor='ne',pady=25)

    refresh_img = PIL.Image.open('refresh.png')
    refresh_img = ImageTk.PhotoImage(refresh_img)
    refresh_canvas = Canvas(user_frame,width=24,height=24,bg=hover_bg)
    refresh_canvas.image = refresh_img
    #refresh_canvas.create_image(0,0,anchor='nw',image=refresh_img)
    #refresh_canvas.pack(side='left',padx=20)
    but = Button(user_frame,image=refresh_img,bg=hover_bg,relief=FLAT,command=refresh_list)
    but.pack(side='left',padx=25)
    display_following()


def remove_unwanted_char(msg):
    char_list = [msg[j] for j in range(len(msg)) if ord(msg[j]) in range(65536)]
    tweet=''
    for j in char_list:
        tweet=tweet+j
    return tweet

#like_image_list = {}

class tweet_box:
    def __init__(self,msg,count):
        self.msg = msg
        self.count = count
        self.l = LabelFrame(rightframe,text=msg.user.screen_name,width=400,
                       height=100,bg=hover_bg,fg='#fff',font=('Dosis',16,'bold'))
        self.profile_img = PIL.Image.open('tweet_photo_'+str(self.count)+'.jpg')
        self.profile_img = ImageTk.PhotoImage(self.profile_img)
        self.profile_img_canvas = Canvas(self.l,width=48,height=48,bg=hover_bg)
        self.profile_img_canvas.image = self.profile_img
        #profile_img_canvas.create_image(0,0,anchor='nw',image=profile_img)
        self.profile_img_label = Label(self.l,image=self.profile_img,bg=hover_bg,relief=FLAT)
        self.tweet_after_process = remove_unwanted_char(self.msg.text)
        self.tweet_msg = Label(self.l,text=self.tweet_after_process,bg=hover_bg,fg='#fff',font=('Dosis',12))
        
        self.check_like_retweet()
        self.display_comp()
    
    def check_like_retweet(self):
        if self.msg.favorited:
            #print(self.msg.id)
            #print('already favorite')
            self.no = 1 #1 means convert to dislike
            like_img = PIL.Image.open('like.png')
            like_img = ImageTk.PhotoImage(like_img)
            like_img_canvas =  Canvas(self.l,width=24,height=24,bg=hover_bg)
            like_img_canvas.image = like_img
            #like_img_canvas.create_image(0,0,anchor='nw',image=like_img)
            self.like_image_label = Label(self.l, image=like_img,bg=hover_bg) 
            self.like_image_label.bind('<Button-1>',lambda a:self.like_unlike(self.msg.id)) #1 means dislike
            #self.like_image_list[msg.id] = like_image_label
        else:
            #print(self.msg.id)
            #print('Not favorite')
            self.no = 0 #0 means convert to like
            like_img = PIL.Image.open('unlike.png')
            like_img = ImageTk.PhotoImage(like_img)
            like_img_canvas =  Canvas(self.l,width=24,height=24,bg=hover_bg)
            like_img_canvas.image = like_img
            #like_img_canvas.create_image(0,0,anchor='nw',image=like_img)
            self.like_image_label = Label(self.l, image=like_img,bg=hover_bg) #0 means like
            self.like_image_label.bind('<Button-1>',lambda a:self.like_unlike(self.msg.id)) 
            #like_image_list[msg.id] = like_image_label
            
        
        if self.msg.retweeted:
            self.retweet_no  = 1 # 1 means to unretweet
            retweet_img = PIL.Image.open('retweet_done.png')
            retweet_img = ImageTk.PhotoImage(retweet_img)
            retweet_img_canvas =  Canvas(self.l,width=24,height=24,bg=hover_bg)
            retweet_img_canvas.image = retweet_img
            #retweet_img_canvas.create_image(0,0,anchor='nw',image=retweet_img)
            self.retweet_img_label = Label(self.l, image=retweet_img,bg=hover_bg)
            self.retweet_img_label.bind('<Button-1>',lambda a:self.re_unretweet(self.msg.id))
        else:
            self.retweet_no  = 0 #0 means to retweet
            retweet_img = PIL.Image.open('retweet_undone.png')
            retweet_img = ImageTk.PhotoImage(retweet_img)
            retweet_img_canvas =  Canvas(self.l,width=24,height=24,bg=hover_bg)
            retweet_img_canvas.image = retweet_img
            #retweet_img_canvas.create_image(0,0,anchor='nw',image=retweet_img)
            self.retweet_img_label = Label(self.l, image=retweet_img,bg=hover_bg)
            self.retweet_img_label.bind('<Button-1>',lambda a:self.re_unretweet(self.msg.id))
        
        time = self.msg.created_at
        self.tweet_time = time.strftime('%d/%m/%y')
        self.lb_time = Label(self.l,text = 'Tweeted on: '+self.tweet_time,bg=hover_bg,fg='#918a83')
        
    def display_comp(self):
        self.l.pack(side=TOP,pady=5,anchor= 'w',padx=15 )
        self.profile_img_label.grid(row=0,column=0,rowspan=2)
        self.tweet_msg.grid(row=0,column=1,rowspan=2,columnspan=4,padx=15)
        self.like_image_label.grid(row=2,column=1)
        self.retweet_img_label.grid(row=2,column=2)
        self.lb_time.grid(row=2,column=3)
    
    def re_unretweet(self,mid):
        if self.retweet_no == 1:
            #print('inside Already favorite',mid)
            api.unretweet(mid)
            retweet_img = PIL.Image.open('retweet_undone.png')
            retweet_img = ImageTk.PhotoImage(retweet_img)
            retweet_img_canvas =  Canvas(self.l,width=24,height=24,bg=hover_bg)
            retweet_img_canvas.image = retweet_img
            self.retweet_img_label.configure(image=retweet_img)
            self.retweet_no = 0
            #like_image_list[mid].configure(image=like_img)
        else:
            #print('inside Not favorite',mid)
            api.retweet(mid)
            retweet_img = PIL.Image.open('retweet_done.png')
            retweet_img = ImageTk.PhotoImage(retweet_img)
            retweet_img_canvas =  Canvas(self.l,width=24,height=24,bg=hover_bg)
            retweet_img_canvas.image = retweet_img
            self.retweet_img_label.configure(image=retweet_img)
            self.retweet_no = 1
            #like_image_list[mid].configure(image=like_img)
    
    
    def like_unlike(self,mid):
    #lobal like_image_label
    #print(mid)
        #for keys in like_image_list.keys():
            #if keys == mid:
        if self.no == 1:
            #print('inside Already favorite',mid)
            api.destroy_favorite(mid)
            like_img = PIL.Image.open('unlike.png')
            like_img = ImageTk.PhotoImage(like_img)
            like_img_canvas =  Canvas(self.l,width=24,height=24,bg=hover_bg)
            like_img_canvas.image = like_img
            self.like_image_label.configure(image=like_img)
            self.no = 0
            #like_image_list[mid].configure(image=like_img)
        else:
            #print('inside Not favorite',mid)
            api.create_favorite(mid)
            like_img = PIL.Image.open('like.png')
            like_img = ImageTk.PhotoImage(like_img)
            like_img_canvas =  Canvas(self.l,width=24,height=24,bg=hover_bg)
            like_img_canvas.image = like_img
            self.like_image_label.configure(image=like_img)
            self.no = 1
            #like_image_list[mid].configure(image=like_img)
    
def display_tweets(timeline):
    pass
def new_screen(last_count,my_timeline):
    unpack_others()
    start_count= last_count + 1
    for i, msg in enumerate(my_timeline):
        if i<=last_count:
            continue
        else:
            download_image_read_tweets(msg.user.profile_image_url,start_count)
            box = tweet_box(msg,start_count)
            start_count = start_count + 1
            if i - 4 == last_count:
                next_button = Button(rightframe,text='Next>>',bg=hover_bg,
                                 fg='#fff',relief=RAISED,font=('Timesnew Roman',14),
                                     command= lambda:new_screen(i,my_timeline))
                next_button.pack(side='right')
                prev_button = Button(rightframe,text='<<Prev',bg=hover_bg,
                                 fg='#fff',relief=RAISED,font=('Timesnew Roman',14),
                                     command=lambda:prev_screen(i+1,my_timeline))
                prev_button.pack(side='right',padx=20)
                return
def prev_screen(last_count,my_timeline):
    unpack_others()
    start_count= last_count - 8
    for i, msg in enumerate(my_timeline):
        if i<start_count:
            continue
        else:
            download_image_read_tweets(msg.user.profile_image_url,start_count)
            box = tweet_box(msg,start_count)
            start_count = start_count + 1
            if i - 3 == last_count - 8:
                next_button = Button(rightframe,text='Next>>',bg=hover_bg,
                                 fg='#fff',relief=RAISED,font=('Timesnew Roman',14),
                                     command= lambda:new_screen(i,my_timeline))
                next_button.pack(side='right')
                prev_button = Button(rightframe,text='<<Prev',bg=hover_bg,
                                 fg='#fff',relief=RAISED,font=('Timesnew Roman',14),
                                     command=lambda:prev_screen(i+1,my_timeline))
                prev_button.pack(side='right',padx=20)
                return
    
def read_tweet():
    global flag_pressed_read
    global flag_pressed_follow
    flag_pressed_read=True
    flag_pressed_follow=False
    Read_tweet.configure(bg=hover_bg)
    following.configure(bg=leave_bg)
    unpack_others()
    my_timeline = api.home_timeline()
    #display_tweets(my_timeline)
    count=0
    for i,msg in enumerate(my_timeline):
        download_image_read_tweets(msg.user.profile_image_url,count)
        box = tweet_box(msg,count)
        
        if i==3: # display only 4 tweets in a screen
            next_button = Button(rightframe,text='Next>>',bg=hover_bg,
                                 fg='#fff',relief=RAISED,font=('Timesnew Roman',14),command= lambda:new_screen(count,my_timeline))
            next_button.pack(side='right')
            prev_button = Button(rightframe,text='<<Prev',bg=hover_bg,
                                 fg='#fff',relief=RAISED,font=('Timesnew Roman',14),command=lambda:new_screen(count,my_timeline))
            prev_button.pack(side='right',padx=20)
            return
        count = count+1
    #for i in like_image_list.keys():
    #    print(i)
    
following = Button(leftframe,text='Show Following',width=15,bg='#fca503',
                   fg='#fff',font=('Bahnschrift Light SemiCondensed',16),relief=FLAT,command=show_following)
following.grid(row=0,column=0,pady=(15,0))
following.bind('<Enter>',lambda x:hover(1))
following.bind('<Leave>',lambda x:leave(1))

Read_tweet = Button(leftframe,text='Read Tweets',width=15,bg='#fca503',
                    fg='#fff',font=('Bahnschrift Light SemiCondensed',16),relief=FLAT,command=read_tweet)
Read_tweet.grid(row=1,column=0)
Read_tweet.bind('<Enter>',lambda x:hover(2))
Read_tweet.bind('<Leave>',lambda x:leave(2))

search_tweet = Button(leftframe,text='Search Tweets',width=15,bg='#fca503',fg='#fff',font=('Bahnschrift Light SemiCondensed',16),relief=FLAT)
search_tweet.grid(row=2,column=0)
search_tweet.bind('<Enter>',lambda x:hover(3))
search_tweet.bind('<Leave>',lambda x:leave(3))

#for i,wid in enumerate(leftframe.winfo_children()):    
#    #print(wid.winfo_class())
#    wid.bind('<Enter>',lambda x:hover(wid))
#    wid.bind('<Leave>',lambda x:leave(wid))

root.mainloop()

# %%
me.profile_image_url
# Out:
# 'http://pbs.twimg.com/profile_images/1313085813102530560/xQ1vxhKi_normal.jpg'

# %%
consumer_key = 'H5Jla4zoZcNLtDiuR125fgPhR'
consumer_secret = 'HWSbxGzQYgEhwOigJCrggYWzuGRKNcBX93CPXiyxi9RYYVrBhc'
callback_uri = 'oob'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
redirect_url = auth.get_authorization_url() 
#webbrowser.open(redirect_url)
#print(redirect_url)
access_token = '493298328-xZkQxyCSr5QkHN8VbGwBaY2SAZNyyH3X3yFrmr6N'
access_secret_token = '3cPqkMk12ixa6GAfSly6W6KwuYdK0Uapw2KDZVEmP0wSI'
auth.set_access_token(access_token,access_secret_token)
api = tweepy.API(auth)

# %%
me = api.me()
print(me.screen_name)
# Out:
# STEVESAMSON2

# %%
print(me.followers_count)
for friend in me.friends():
    print(friend.screen_name)
    print('************************************************')
    print(friend.profile_image_url)
    print('************************************************')
# Out:
# 4
# akshaykumar
# ************************************************
# http://pbs.twimg.com/profile_images/1263033005758545921/4K0V7QQi_normal.jpg
# ************************************************
# WHO
# ************************************************
# http://pbs.twimg.com/profile_images/875476478988886016/_l61qZdR_normal.jpg
# ************************************************
# Frankeudy
# ************************************************
# http://pbs.twimg.com/profile_images/482367489465016320/LFRztbpH_normal.jpeg
# ************************************************

# %% [markdown]
# # FOLLOW UNFOLLOW

# %%
user = api.get_user('akshaykumar')
print(user.followers_count)
#me = api.me()
#print(me.followers_count,me.friends_count)
#for friend in me.friends():
#    print(friend.screen_name,friend.followers_count,friend.friends_count)

api.create_friendship('Cristiano')
# Out:
# 39359648
# User(_api=<tweepy.api.API object at 0x000001E68A5153C8>, _json={'id': 155659213, 'id_str': '155659213', 'name': 'Cristiano Ronaldo', 'screen_name': 'Cristiano', 'location': 'Turim, Piemonte', 'description': 'This Privacy Policy addresses the collection and use of personal information - https://t.co/Jp6yh1T58c', 'url': 'https://t.co/VcAXB9ryty', 'entities': {'url': {'urls': [{'url': 'https://t.co/VcAXB9ryty', 'expanded_url': 'http://www.facebook.com/cristiano', 'display_url': 'facebook.com/cristiano', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/Jp6yh1T58c', 'expanded_url': 'http://www.cristianoronaldo.com/terms', 'display_url': 'cristianoronaldo.com/terms', 'indices': [79, 102]}]}}, 'protected': False, 'followers_count': 88232563, 'friends_count': 51, 'listed_count': 83648, 'created_at': 'Mon Jun 14 19:09:20 +0000 2010', 'favourites_count': 2, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 3585, 'lang': None, 'status': {'created_at': 'Fri Oct 02 11:00:01 +0000 2020', 'id': 1311984277668544517, 'id_str': '1311984277668544517', 'text': 'Be bold. Be brave. Be confident.\nNever let your anxiety hold you back. \nWhat about you? Retweet and share three tra… https://t.co/uVJfveY4CA', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/uVJfveY4CA', 'expanded_url': 'https://twitter.com/i/web/status/1311984277668544517', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 6486, 'favorite_count': 82491, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': '080101', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1157313327867092993/a09TxL_1_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1157313327867092993/a09TxL_1_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/155659213/1564759975', 'profile_link_color': '1643C9', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': '838387', 'profile_text_color': '0D0D0D', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'translator_type': 'regular'}, id=155659213, id_str='155659213', name='Cristiano Ronaldo', screen_name='Cristiano', location='Turim, Piemonte', description='This Privacy Policy addresses the collection and use of personal information - https://t.co/Jp6yh1T58c', url='https://t.co/VcAXB9ryty', entities={'url': {'urls': [{'url': 'https://t.co/VcAXB9ryty', 'expanded_url': 'http://www.facebook.com/cristiano', 'display_url': 'facebook.com/cristiano', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/Jp6yh1T58c', 'expanded_url': 'http://www.cristianoronaldo.com/terms', 'display_url': 'cristianoronaldo.com/terms', 'indices': [79, 102]}]}}, protected=False, followers_count=88232563, friends_count=51, listed_count=83648, created_at=datetime.datetime(2010, 6, 14, 19, 9, 20), favourites_count=2, utc_offset=None, time_zone=None, geo_enabled=True, verified=True, statuses_count=3585, lang=None, status=Status(_api=<tweepy.api.API object at 0x000001E68A5153C8>, _json={'cr ...

# %%
api.destroy_friendship('Cristiano')
# Out:
# User(_api=<tweepy.api.API object at 0x000001E68A5153C8>, _json={'id': 155659213, 'id_str': '155659213', 'name': 'Cristiano Ronaldo', 'screen_name': 'Cristiano', 'location': 'Turim, Piemonte', 'description': 'This Privacy Policy addresses the collection and use of personal information - https://t.co/Jp6yh1T58c', 'url': 'https://t.co/VcAXB9ryty', 'entities': {'url': {'urls': [{'url': 'https://t.co/VcAXB9ryty', 'expanded_url': 'http://www.facebook.com/cristiano', 'display_url': 'facebook.com/cristiano', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/Jp6yh1T58c', 'expanded_url': 'http://www.cristianoronaldo.com/terms', 'display_url': 'cristianoronaldo.com/terms', 'indices': [79, 102]}]}}, 'protected': False, 'followers_count': 88232596, 'friends_count': 51, 'listed_count': 83648, 'created_at': 'Mon Jun 14 19:09:20 +0000 2010', 'favourites_count': 2, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 3585, 'lang': None, 'status': {'created_at': 'Fri Oct 02 11:00:01 +0000 2020', 'id': 1311984277668544517, 'id_str': '1311984277668544517', 'text': 'Be bold. Be brave. Be confident.\nNever let your anxiety hold you back. \nWhat about you? Retweet and share three tra… https://t.co/uVJfveY4CA', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/uVJfveY4CA', 'expanded_url': 'https://twitter.com/i/web/status/1311984277668544517', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 6486, 'favorite_count': 82494, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': '080101', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1157313327867092993/a09TxL_1_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1157313327867092993/a09TxL_1_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/155659213/1564759975', 'profile_link_color': '1643C9', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': '838387', 'profile_text_color': '0D0D0D', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'translator_type': 'regular'}, id=155659213, id_str='155659213', name='Cristiano Ronaldo', screen_name='Cristiano', location='Turim, Piemonte', description='This Privacy Policy addresses the collection and use of personal information - https://t.co/Jp6yh1T58c', url='https://t.co/VcAXB9ryty', entities={'url': {'urls': [{'url': 'https://t.co/VcAXB9ryty', 'expanded_url': 'http://www.facebook.com/cristiano', 'display_url': 'facebook.com/cristiano', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/Jp6yh1T58c', 'expanded_url': 'http://www.cristianoronaldo.com/terms', 'display_url': 'cristianoronaldo.com/terms', 'indices': [79, 102]}]}}, protected=False, followers_count=88232596, friends_count=51, listed_count=83648, created_at=datetime.datetime(2010, 6, 14, 19, 9, 20), favourites_count=2, utc_offset=None, time_zone=None, geo_enabled=True, verified=True, statuses_count=3585, lang=None, status=Status(_api=<tweepy.api.API object at 0x000001E68A5153C8>, _json={'cr ...

# %%
new_status = api.update_status('Hello everyone, new day brings new hopes and excitment I hope all of u out their feeling the same')

# %%
new_status.destroy()
# Out:
# Status(_api=<tweepy.api.API object at 0x000001F5E88F52E8>, _json={'created_at': 'Mon Oct 05 02:05:42 +0000 2020', 'id': 1312936974089478146, 'id_str': '1312936974089478146', 'text': 'Hello everyone, new day brings new hopes and excitment I hope all of u out their feeling the same', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://www.google.com" rel="nofollow">Studentmachinelearning</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 493298328, 'id_str': '493298328', 'name': 'STEVE SAMSON', 'screen_name': 'STEVESAMSON2', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 4, 'friends_count': 3, 'listed_count': 0, 'created_at': 'Wed Feb 15 17:11:42 +0000 2012', 'favourites_count': 36, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 42, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '1A1B1F', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '2FC2EF', 'profile_sidebar_border_color': '181A1E', 'profile_sidebar_fill_color': '252429', 'profile_text_color': '666666', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': True, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 10, 5, 2, 5, 42), id=1312936974089478146, id_str='1312936974089478146', text='Hello everyone, new day brings new hopes and excitment I hope all of u out their feeling the same', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='Studentmachinelearning', source_url='https://www.google.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x000001F5E88F52E8>, _json={'id': 493298328, 'id_str': '493298328', 'name': 'STEVE SAMSON', 'screen_name': 'STEVESAMSON2', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 4, 'friends_count': 3, 'listed_count': 0, 'created_at': 'Wed Feb 15 17:11:42 +0000 2012', 'favourites_count': 36, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 42, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '1A1B1F', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '2FC2EF', 'profile_sidebar_border_color': '181A1E', 'profile_sidebar_fill_color': '252429', 'profile_text_color': '666666', 'profile_use_background_image': True, 'has_extended_pr ...

# %%
dir(new_status)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'author',
#  'contributors',
#  'coordinates',
#  'created_at',
#  'destroy',
#  'entities',
#  'favorite',
#  'favorite_count',
#  'favorited',
#  'geo',
#  'id',
#  'id_str',
#  'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'is_quote_status',
#  'lang',
#  'parse',
#  'parse_list',
#  'place',
#  'retweet',
#  'retweet_count',
#  'retweeted',
#  'retweets',
#  'source',
#  'source_url',
#  'text',
#  'truncated',
#  'user']

# %%
img_obj = api.media_upload('gm.jpg')

# %%
new_status = api.update_status('Hello everyone, new day brings new hopes and excitment I hope all of u out their feeling the same',media_ids=[img_obj.media_id_string])

# %%
my_timeline = api.home_timeline()
for msg in my_timeline:
    keys = vars(msg).keys()
    for k in keys:
        print(k)
    #print(msg.text)
# Out:
# _api
# _json
# created_at
# id
# id_str
# text
# truncated
# entities
# source
# source_url
# in_reply_to_status_id
# in_reply_to_status_id_str
# in_reply_to_user_id
# in_reply_to_user_id_str
# in_reply_to_screen_name
# author
# user
# geo
# coordinates
# place
# contributors
# is_quote_status
# retweet_count
# favorite_count
# favorited
# retweeted
# possibly_sensitive
# possibly_sensitive_appealable
# lang
# _api
# _json
# created_at
# id
# id_str
# text
# truncated
# entities
# source
# source_url
# in_reply_to_status_id
# in_reply_to_status_id_str
# in_reply_to_user_id
# in_reply_to_user_id_str
# in_reply_to_screen_name
# author
# user
# geo
# coordinates
# place
# contributors
# is_quote_status
# retweet_count
# favorite_count
# favorited
# retweeted
# lang
# _api
# _json
# created_at
# id
# id_str
# text
# truncated
# entities
# source
# source_url
# in_reply_to_status_id
# in_reply_to_status_id_str
# in_reply_to_user_id
# in_reply_to_user_id_str
# in_reply_to_screen_name
# author
# user
# geo
# coordinates
# place
# contributors
# is_quote_status
# retweet_count
# favorite_count
# favorited
# retweeted
# lang
# _api
# _json
# created_at
# id
# id_str
# text
# truncated
# entities
# extended_entities
# source
# source_url
# in_reply_to_status_id
# in_reply_to_status_id_str
# in_reply_to_user_id
# in_reply_to_user_id_str
# in_reply_to_screen_name
# author
# user
# geo
# coordinates
# place
# contributors
# is_quote_status
# retweet_count
# favorite_count
# favorited
# retweeted
# possibly_sensitive
# possibly_sensitive_appealable
# lang
# _api
# _json
# created_at
# id
# id_str
# text
# truncated
# entities
# extended_entities
# source
# source_url
# in_reply_to_status_id
# in_reply_to_status_id_str
# in_reply_to_user_id
# in_reply_to_user_id_str
# in_reply_to_screen_name
# author
# user
# geo
# coordinates
# place
# contributors
# is_quote_status
# retweet_count
# favorite_count
# favorited
# retweeted
# possibly_sensitive
# possibly_sensitive_appealable
# lang
# _api
# _json
# created_at
# id
# id_str
# text
# truncated
# entities
# source
# source_url
# in_reply_to_status_id
# in_reply_to_status_id_str
# in_reply_to_user_id
# in_reply_to_user_id_str
# in_reply_to_screen_name
# author
# user
# geo
# coordinates
# place
# contributors
# is_quote_status
# retweet_count
# favorite_count
# favorited
# retweeted
# lang
# _api
# _json
# created_at
# id
# id_str
# text
# truncated
# entities
# source
# source_url
# in_reply_to_status_id
# in_reply_to_status_id_str
# in_reply_to_user_id
# in_reply_to_user_id_str
# in_reply_to_screen_name
# author
# user
# geo
# coordinates
# place
# contributors
# is_quote_status
# retweet_count
# favorite_count
# favorited
# retweeted
# lang
# _api
# _json
# created_at
# id
# id_str
# text
# truncated
# entities
# extended_entities
# source
# source_url
# in_reply_to_status_id
# in_reply_to_status_id_str
# in_reply_to_user_id
# in_reply_to_user_id_str
# in_reply_to_screen_name
# author
# user
# geo
# coordinates
# place
# contributors
# is_quote_status
# retweet_count
# favorite_count
# favorited
# retweeted
# possibly_sensitive
# possibly_sensitive_appealable
# lang
# _api
# _json
# created_at
# id
# id_str
# text
# truncated
# entities
# source
# source_url
# in_reply_to_status_id
# in_reply_to_status_id_str
# in_reply_to_user_id
# in_reply_to_user_id_str
# in_reply_to_screen_name
# author
# user
# geo
# coordinates
# place
# contributors
# is_quote_status
# retweet_count
# favorite_count
# favorited
# retweeted
# possibly_sensitive
# possibly_sensitive_appealable
# lang
# _api
# _json
# created_at
# id
# id_str
# text
# truncated
# entities
# extended_entities
# source
# source_url
# in_reply_to_status_id
# in_reply_to_status_id_str
# in_reply_to_user_id
# in_reply_to_user_id_str
# in_reply_to_screen_name
# author
# user
# geo
# coordinates
# place
# contributors
# retweeted_status
# is_quote_status
# retweet_count
# favorite_count
# favorited
# retweeted
# possibly_sensitive
# possibly_sensitive_appealable
# lang
# _api
# _json
# created_at
# id
# id_str
# text
# truncated
# entities
# source
# source_url
# in_reply_to_status_id
# in_reply_to_status_id_str
# in_reply_to_user_id
# in_reply_to_user_id_str
# in_reply_to_screen_name
# author
# user
# geo
# coordinates
# place
# contributors
# is_quote_status
# retweet_count
# favorite_count
# favorited
# retweeted
# lang
# _api
# _json
# created_at
# id
# id_str
# text
# truncated
# entities
# extended_entities
# source
# source_url
# in_reply_to_status_id
# in_reply_to_status_id_str
# in_reply_to_user_id
# in_reply_to_user_id_str
# in_reply_to_screen_name
# author
# user
# geo
# coordinates
# place
# contributors
# is_quote_status
# retweet_count
# favorite_count
# favorited
# retweeted
# possibly_sensitive
# possibly_sensitive_appealable
# lang
# _api
# _json
# created_at
# id
# id_str
# text
# truncated
# entities
# source
# source_url
# in_reply_to_status_id
# in_reply_to_status_id_str
# in_reply_to_user_id
# in_reply_to_user_id_str
# in_reply_to_screen_name
# author
# user
# geo
# coordinates
# place
# contributors
# is_quote_status
# retweet_count
# favorite_count
# favorited
# retweeted
# lang
# _api
# _json
# created_at
# id
# id_str
# text
# truncated
# entities
# source
# source_url
# in_reply_to_status_id
# in_reply_to_status_id_str
# in_reply_to_user_id
# in_reply_to_user_id_str
# in_reply_to_screen_name
# author
# user
# geo
# coordinates
# place
# contributors
# is_quote_status
# retweet_count
# favorite_count
# favorited
# retweeted
# possibly_sensitive
# possibly_sensitive_appealable
# lang
# _api
# _json
# created_at
# id
# id_str
# text
# truncated
# entities
# source
# source_url
# in_reply_to_status_id
# in_reply_to_status_id_str
# in_reply_to_user_id
# in_reply_to_user_id_str
# in_reply_to_screen_name
# author
# user
# geo
# coordinates
# place
# contributors
# is_quote_status
# retweet_count
# favorite_count
# favorited
# retweeted
# lang
# _api
# _json
# created_at
# id
# id_str
# text
# truncated
# entities
# source
# source_url
# in_reply_to_status_id
# in_reply_to_status_id_str
# in_reply_to_user_id
# in_reply_to_user_id_str
# in_reply_to_screen_name
# author
# user
# geo
# coordinates
# place
# contributors
# is_quote_status
# retweet_count
# favorite_count
# favorited
# retweeted
# possibly_sensitive
# possibly_sensitive_appealable
# lang
# _api
# _json
# created_at
# id
# id_str
# text
# truncated
# entities
# source
# source_url
# in_reply_to_status_id
# in_reply_to_status_id_str
# in_reply_to_user_id
# in_reply_to_user_id_str
# in_reply_to_screen_name
# author
# user
# geo
# coordinates
# place
# contributors
# is_quote_status
# retweet_count
# favorite_count
# favorited
# retweeted
# possibly_sensitive
# possibly_sensitive_appealable
# lang
# _api
# _json
# created_at
# id
# id_str
# text
# truncated
# entities
# source
# source_url
# in_reply_to_status_id
# in_reply_to_status_id_str
# in_reply_to_user_id
# in_reply_to_user_id_str
# in_reply_to_screen_name
# author
# user
# geo
# coordinates
# place
# contributors
# retweeted_status
# is_quote_status
# retweet_count
# favorite_count
# favorited
# retweeted
# lang

# %%
len(my_timeline)
# Out:
# 20

# %%
#from datetime import datetime
my_timeline = api.home_timeline()
for i,a in enumerate(my_timeline):
#a.favorited
#api.destroy_favorite(a.id)
#a.retweet_count
#a.favorite_count
#d = a.created_at
#d.strftime('%d/%m/%y')
#a.retweeted
#a.user.profile_image_url
    print(a.user.screen_name,a.id,a.text)
    if i==5:
        break
# Out:
# realDonaldTrump 1313584866932527105 How does Biden lead in Pennsylvania Polls when he is against Fracking (JOBS!), 2nd Amendment and Religion? Fake Pol… https://t.co/syjQVtnhsm
# Cristiano 1313573447121993728 É sempre um sentimento especial representar o nosso país!🇵🇹👏🏽💪🏽
# #todosportugal https://t.co/yTYT5CKZtK
# realDonaldTrump 1313572685251837958 RT @GOP: 🗳️ 🗳️ 🗳️
#
# For more information, visit ➡️ https://t.co/lQYB8jZfOp https://t.co/Vv3e6ZnnYC
# realDonaldTrump 1313551798142152704 ...also coming back in record numbers. We are leading the World in Economic Recovery, and THE BEST IS YET TO COME!
# realDonaldTrump 1313551796644831233 ...@senatemajldr Mitch McConnell not to delay, but to instead focus full time on approving my outstanding nominee t… https://t.co/WXanZgOS9b
# realDonaldTrump 1313551795646541824 ...request, and looking to the future of our Country. I have instructed my representatives to stop negotiating unti… https://t.co/0wQXlPiQNE

# %%
#a.id
if a.favorited:
    api.destroy_favorite(1313538262632464387)
else:
    api.create_favorite(1313538262632464387)
# Out:
# Status(_api=<tweepy.api.API object at 0x000001F7053E0A20>, _json={'created_at': 'Tue Oct 06 17:55:00 +0000 2020', 'id': 1313538262632464387, 'id_str': '1313538262632464387', 'text': 'A strong performance by @mipaltan while batting &amp; bowling.\nThey started really well by picking early wickets and co… https://t.co/TfycHt5DGP', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'mipaltan', 'name': 'Mumbai Indians', 'id': 106345557, 'id_str': '106345557', 'indices': [24, 33]}], 'urls': [{'url': 'https://t.co/TfycHt5DGP', 'expanded_url': 'https://twitter.com/i/web/status/1313538262632464387', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [121, 144]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 135421739, 'id_str': '135421739', 'name': 'Sachin Tendulkar', 'screen_name': 'sachin_rt', 'location': 'ÜT: 18.986431,72.823769', 'description': 'Proud Indian', 'url': 'https://t.co/mQgltaWGbQ', 'entities': {'url': {'urls': [{'url': 'https://t.co/mQgltaWGbQ', 'expanded_url': 'http://bit.ly/100MBApp', 'display_url': 'bit.ly/100MBApp', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 34131224, 'friends_count': 80, 'listed_count': 22368, 'created_at': 'Wed Apr 21 07:42:23 +0000 2010', 'favourites_count': 199, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 3681, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1260456676890742786/MzGhbLvr_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1260456676890742786/MzGhbLvr_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/135421739/1578061223', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1048, 'favorite_count': 8242, 'favorited': True, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 10, 6, 17, 55), id=1313538262632464387, id_str='1313538262632464387', text='A strong performance by @mipaltan while batting &amp; bowling.\nThey started really well by picking early wickets and co… https://t.co/TfycHt5DGP', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'mipaltan', 'name': 'Mumbai Indians', 'id': 106345557, 'id_str': '106345557', 'indices': [24, 33]}], 'urls': [{'url': 'https://t.co/TfycHt5DGP', 'expanded_url': 'https://twitter.com/i/web/status/1313538262632464387', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [121, 144]}]}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x000001F7053E0A20>, _json={'id': 135421739, 'id_str': '135421739', 'name': 'Sachin Tendulkar', 'screen_name': 'sachin_rt', 'location': 'ÜT: 18.986431,72.823769', 'description': 'Proud Indian', 'url': 'https://t.co/mQgltaWGbQ', 'entities': {'url': {'urls': [ ...

# %%
dir(a)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'author',
#  'contributors',
#  'coordinates',
#  'created_at',
#  'destroy',
#  'entities',
#  'favorite',
#  'favorite_count',
#  'favorited',
#  'geo',
#  'id',
#  'id_str',
#  'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'is_quote_status',
#  'lang',
#  'parse',
#  'parse_list',
#  'place',
#  'retweet',
#  'retweet_count',
#  'retweeted',
#  'retweets',
#  'source',
#  'source_url',
#  'text',
#  'truncated',
#  'user']

# %%
#first_msg = my_timeline[1]
dir(first_msg.user)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'contributors_enabled',
#  'created_at',
#  'default_profile',
#  'default_profile_image',
#  'description',
#  'entities',
#  'favourites_count',
#  'follow',
#  'follow_request_sent',
#  'followers',
#  'followers_count',
#  'followers_ids',
#  'following',
#  'friends',
#  'friends_count',
#  'geo_enabled',
#  'has_extended_profile',
#  'id',
#  'id_str',
#  'is_translation_enabled',
#  'is_translator',
#  'lang',
#  'listed_count',
#  'lists',
#  'lists_memberships',
#  'lists_subscriptions',
#  'location',
#  'name',
#  'notifications',
#  'parse',
#  'parse_list',
#  'profile_background_color',
#  'profile_background_image_url',
#  'profile_background_image_url_https',
#  'profile_background_tile',
#  'profile_banner_url',
#  'profile_image_url',
#  'profile_image_url_https',
#  'profile_link_color',
#  'profile_sidebar_border_color',
#  'profile_sidebar_fill_color',
#  'profile_text_color',
#  'profile_use_background_image',
#  'protected',
#  'screen_name',
#  'statuses_count',
#  'time_zone',
#  'timeline',
#  'translator_type',
#  'unfollow',
#  'url',
#  'utc_offset',
#  'verified']

# %%
#first_msg.user.screen_name
#first_msg.user.profile_image_url
#first_msg.user.followers_count
first_msg.text
#first_msg.user.name
#first_msg.user.profile_background_image_url_https
# Out:
# 'Join @momgerm, WHO Goodwill Ambassador for Mental Health and President and Co-Founder (with her daughter @ladygaga)… https://t.co/PqRtCbRUhK'

# %%
user = api.get_user('akshaykumar')
user_timeline = user.timeline()
print(user_timeline[0].id)
print(user_timeline[0].user.screen_name)
# Out:
# 1312996146445389824
# akshaykumar

# %% [markdown]
# # RETWEET LIKE AND REPLY,STATUS UPDATE

# %%
my_timeline = api.home_timeline()
#print(my_timeline[0].id,my_timeline[0].text)
#api.retweet(my_timeline[0].id)
api.unretweet(my_timeline[0].id)
#api.retweet(user_timeline[0].id)
#api.create_favorite(user_timeline[0].id)
#api.destroy_favorite(user_timeline[0].id)

#
#my_reply=api.update_status(f"@{user_timeline[0].user.screen_name}You are a wonderful actor",user_timeline[0].id)
# Out:
# Status(_api=<tweepy.api.API object at 0x000001DFBCAF6C50>, _json={'created_at': 'Tue Oct 06 20:14:49 +0000 2020', 'id': 1313573447121993728, 'id_str': '1313573447121993728', 'text': 'É sempre um sentimento especial representar o nosso país!🇵🇹👏🏽💪🏽\n#todosportugal https://t.co/yTYT5CKZtK', 'truncated': False, 'entities': {'hashtags': [{'text': 'todosportugal', 'indices': [64, 78]}], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1313573442092965889, 'id_str': '1313573442092965889', 'indices': [79, 102], 'media_url': 'http://pbs.twimg.com/media/EjrAFgJWoAEYSoQ.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EjrAFgJWoAEYSoQ.jpg', 'url': 'https://t.co/yTYT5CKZtK', 'display_url': 'pic.twitter.com/yTYT5CKZtK', 'expanded_url': 'https://twitter.com/Cristiano/status/1313573447121993728/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 640, 'resize': 'fit'}, 'medium': {'w': 1080, 'h': 1017, 'resize': 'fit'}, 'large': {'w': 1080, 'h': 1017, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1313573442092965889, 'id_str': '1313573442092965889', 'indices': [79, 102], 'media_url': 'http://pbs.twimg.com/media/EjrAFgJWoAEYSoQ.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EjrAFgJWoAEYSoQ.jpg', 'url': 'https://t.co/yTYT5CKZtK', 'display_url': 'pic.twitter.com/yTYT5CKZtK', 'expanded_url': 'https://twitter.com/Cristiano/status/1313573447121993728/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 640, 'resize': 'fit'}, 'medium': {'w': 1080, 'h': 1017, 'resize': 'fit'}, 'large': {'w': 1080, 'h': 1017, 'resize': 'fit'}}}, {'id': 1313573442134908934, 'id_str': '1313573442134908934', 'indices': [79, 102], 'media_url': 'http://pbs.twimg.com/media/EjrAFgTWoAY3zbg.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EjrAFgTWoAY3zbg.jpg', 'url': 'https://t.co/yTYT5CKZtK', 'display_url': 'pic.twitter.com/yTYT5CKZtK', 'expanded_url': 'https://twitter.com/Cristiano/status/1313573447121993728/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1080, 'h': 1017, 'resize': 'fit'}, 'large': {'w': 1080, 'h': 1017, 'resize': 'fit'}, 'small': {'w': 680, 'h': 640, 'resize': 'fit'}}}, {'id': 1313573442097156100, 'id_str': '1313573442097156100', 'indices': [79, 102], 'media_url': 'http://pbs.twimg.com/media/EjrAFgKWkAQAkpJ.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EjrAFgKWkAQAkpJ.jpg', 'url': 'https://t.co/yTYT5CKZtK', 'display_url': 'pic.twitter.com/yTYT5CKZtK', 'expanded_url': 'https://twitter.com/Cristiano/status/1313573447121993728/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 640, 'resize': 'fit'}, 'medium': {'w': 1080, 'h': 1017, 'resize': 'fit'}, 'large': {'w': 1080, 'h': 1017, 'resize': 'fit'}}}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 155659213, 'id_str': '155659213', 'name': 'Cristiano Ronaldo', 'screen_name': 'Cristiano', 'location': 'Turim, Piemonte', 'description': 'This Privacy Policy addresses the collection and use of personal information - https://t.co/Jp6yh1T58c', 'url': 'https://t.co/VcAXB9ryty', 'entities': {'url': {'urls': [{'url': 'https://t.co/VcAXB9ryty', 'expanded_url': 'http://www.facebook.com/cristiano', 'display_url': 'facebook.com/cristiano', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/Jp6yh1T58c', 'expanded_url': 'http://www.cristianoronaldo.com/terms', 'display_url': 'cristianoronaldo.com/terms', 'indices': [79, 102]}]}}, 'protected': False, 'followers_count': 88255342, 'friends_count': 51, 'listed_count': 83646, 'created_at': 'Mon Jun 14 19:09:20 +0000 2010', 'favourites_count': 2, 'utc_offset': N ...

# %%
user_timeline[0].user.screen_name
# Out:
# 'akshaykumar'

# %%
print(my_reply.id,my_reply.user.screen_name)
# Out:
# 1313288288468267008 STEVESAMSON2

# %%
user = api.get_user('akshaykumar')
user_timeline = user.timeline()
for msg in user_timeline:
    print(msg.text)
    print(msg.favorite_count)
    print(msg.retweet_count)
# Out:
# @monishaadvani @madhubhojwani @nikkhiladvani @EmmayEntertain @poojafilms @saregamaglobal
# 5257
# 568
# Go BellBottom! Here’s a thrilling throwback to the 80s. 🙌🏼 Presenting #BellBottomTeaser
# https://t.co/U9KEoyggXj
# .… https://t.co/FAMKM8q9gH
# 11839
# 2176
# Bahot dino se mann mein kuch baat thi lekin samajh nahi aa raha tha kya kahoon, kisse kahoon. Aaj socha aap logon s… https://t.co/9c3MgBeUB5
# 145862
# 18298
# I am thankful for a home that is filled with the sounds of life that make me feel safe, and that fill my life with… https://t.co/FqdT8casN0
# 14014
# 1582
# @monishaadvani @madhubhojwani @nikkhiladvani @EmmayEntertain @poojafilms
# 3655
# 349
# Mission accomplished! After a long but fruitful schedule, grateful to have shot and completed #Bellbottom during th… https://t.co/z8QPM5gFdf
# 22269
# 1797
# @Shabinaa_Ent @tusshkapoor @foxstarhindi #CapeOfGoodFilms #ShabinaaEntertainment  #TussharEntertainmentHouse… https://t.co/tsRopHLVPc
# 2424
# 345
# Keep your Remote, Popcorn🍿 Nachos, Coke🥤 Cushions and blankets ready as #LaxmmiBomb 💥 is coming to your home soon.… https://t.co/CuTsZFy8zt
# 11815
# 1653
# RT @LivguardEnergy: Presenting the expert solar solution for your homes with Livguard solar rooftop solutions. An ideal energy solution bui…
# 0
# 567
# @monishaadvani @madhubhojwani @nikkhiladvani @EmmayEntertain @poojafilms
# 6335
# 564
# Alone we can do so little, together we can do so much. Its teamwork and I am grateful to each and every member of t… https://t.co/xFFNdlEkvv
# 37613
# 3398
# So many happy faces in one frame...that’s the result of a good schedule. Goodbye Glasgow, hello London 😁… https://t.co/Z0wcUSkSRs
# 19318
# 1678
# Angry &amp; Frustrated!Such brutality in #Hathras gangrape.When will this stop?Our laws &amp; their enforcement must be so… https://t.co/EoQrBPz1Pg
# 104590
# 17363
# You are my definition of perfect! And I love you so much more than just to the moon and back ♥️ #HappyDaughtersDay… https://t.co/LEbPCV7Lf3
# 105525
# 4152
# Thank you so much Arti...this is lovely.  Showed it to Nitara as well, she smiled shyly and said thank you ☺️ https://t.co/ppnAtVaHwk
# 16513
# 1283
# As much as everyone would like to see the back of 2020, I wish this moment, this year, this chance to spend so much… https://t.co/zoJzVE8LYQ
# 83784
# 3840
# Deeply saddened to hear about the demise of Balasubrahmanyam ji.Just a few months back I’d interacted with him duri… https://t.co/Wa5wsQc1gJ
# 61336
# 5700
# #CapeOfGoodFilms @iAmAzure @ZeeStudios_ @ZeeMusicCompany
# 3362
# 379
# The love continues to grow! This hearty salute to our heroes will be eternal, #TeriMitti hits 300M+ views!
#
# #Kesari… https://t.co/quQPnveMKw
# 17328
# 1934
# Had a rather blessed morning...spent ten minutes in this Gurudwara today and counted my blessings. I feel a sense o… https://t.co/OjkD7JdvEC
# 38443
# 2554

# %%
dir(first_msg.user)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'contributors_enabled',
#  'created_at',
#  'default_profile',
#  'default_profile_image',
#  'description',
#  'entities',
#  'favourites_count',
#  'follow',
#  'follow_request_sent',
#  'followers',
#  'followers_count',
#  'followers_ids',
#  'following',
#  'friends',
#  'friends_count',
#  'geo_enabled',
#  'has_extended_profile',
#  'id',
#  'id_str',
#  'is_translation_enabled',
#  'is_translator',
#  'lang',
#  'listed_count',
#  'lists',
#  'lists_memberships',
#  'lists_subscriptions',
#  'location',
#  'name',
#  'notifications',
#  'parse',
#  'parse_list',
#  'profile_background_color',
#  'profile_background_image_url',
#  'profile_background_image_url_https',
#  'profile_background_tile',
#  'profile_banner_url',
#  'profile_image_url',
#  'profile_image_url_https',
#  'profile_link_color',
#  'profile_sidebar_border_color',
#  'profile_sidebar_fill_color',
#  'profile_text_color',
#  'profile_use_background_image',
#  'protected',
#  'screen_name',
#  'statuses_count',
#  'time_zone',
#  'timeline',
#  'translator_type',
#  'unfollow',
#  'url',
#  'utc_offset',
#  'verified']

# %% [markdown]
# # CREATE/DESTROY FRIENDSHIP

# %%
user = api.get_user('akshaykumar')

# %%
my_new_friends = []
user_friends = user.friends()
for friend in user_friends:
    if friend.followers_count > 300 and friend.friends_count<300:
        my_new_friends.append(friend.screen_name)
        relationship = api.create_friendship(friend.screen_name)

# %% [markdown]
# # To get more items back from tweepy than only 20

# %%
#First way
api.home_timeline(count=40)

# %%
#second way
for i,status in enumerate(tweepy.Cursor(api.home_timeline).items(50)):
    print(i,status.text)

# %%
#timeline of some other user
other_user = 'therock'
for i,status in enumerate(tweepy.Cursor(api.user_timeline,screen_name=other_user).items(20)):
    print(i, status.text)
# Out:
# 0 Appreciate that man. Glad my Lakers’ speech can help you find and create your own path. Have a productive week 🤙🏾 https://t.co/fkw846ysUa
# 1 Just posted a video https://t.co/zVORmjCFho
# 2 Good Lord this was an awesome time in pro wrestling. Electrifying crowds! 👀
# the crazy stunner bumps I would take s… https://t.co/hvGqjynr66
# 3 We smell it.
# Welcome back G!
# @49ers @gkittle46 #bringit
# #ninersVeagles https://t.co/pKzNGxHhaG
# 4 Grateful to share our very first @Teremana commercial that will air tonight and throughout the #NBAFinals
# I founde… https://t.co/1jL0W9rcCX
# 5 An honor wishing my dear buddy #GrandmaGrover an amazing 101st birthday!! 🎂🎉🙏🏾
#
# Love how she makes sure her hair is… https://t.co/ednU9DDtkc
# 6 XFL returns SPRING 2022 🏈
#
# As owners, we’re proud to champion our XFL players, coaches, cities and fans into an ele… https://t.co/lJsYnyAv3a
# 7 #YOUNGROCK
# @adriangroulx is our anchor👊🏾At 10, I was rambunctious as all hell 😈, girl crazy 😜 &amp; loved pro wrestling… https://t.co/T8HvTC15zP
# 8 #YOUNGROCK
# This role is special! Playing my grandma, Lia Maivia is, Ana Tuisila. Lia was pro wrestling’s first wome… https://t.co/GnvuZU5dKI
# 9 #YOUNGROCK
# Coming in hot &amp; lowering the U of MIAMI BOOM 🏈💥 is @ulilatukefu! Playing at THE U were my defining years… https://t.co/ESCBZ0z7YO
# 10 #YOUNGROCK
# Playing my pops, Rocky “Soulman” Johnson is @iJosephAnderson💥 As you know, my dad passed away this year,… https://t.co/8lq4efW6dD
# 11 #YOUNGROCK
# Playing my mom @atajohnson1 aka Mama Rock is the talented &amp; lovely Stacey Leilua. You know my moms story… https://t.co/U5MrIEiRsn
# 12 Ladies &amp; gents, here’s the cast of our new @NBC comedy, #YOUNGROCK. A series based on my wild and unpredictable chi… https://t.co/XQ4txFUZfy
# 13 Heart stoppin’ elbow droppin’ 💪🏾
# * Check out the crowd all standing UP... these were VERY special, fun and cool tim… https://t.co/DR5uUYCLjc
# 14 A critical conversation - voting. Our voice. Our power.
#
# And no matter how strongly your opinion may differ from m… https://t.co/F4beLNv9f5
# 15 As a political independent &amp; centrist, I’ve voted for both parties in the past. In this critical presidential elect… https://t.co/xWnR9xbJzA
# 16 Wow! Blachowicz called it - 2nd round KO. Helluva win, congrats champ! Reyes will be back even stronger.
# #andnew #UFC253
# 17 @ShamrockKen Ken - I’ll hit you on the DM, I need your email addy to send your induction vid 👍🏾
# 18 Always protect the Rock 😂 🏈
# SNF!! Bring it on.
# #noturnovers https://t.co/jCrlNNn26g
# 19 RT @Spotify: The only thing missing from your workout is @TheRock. Listen to his Progress Workout playlist now for pumped up tunes and moti…

# %%
#The people followed by the specified user
other_user= 'therock'
the_rock_friends=[]
for i, id in enumerate(tweepy.Cursor(api.friends_ids,screen_name=other_user).items(30)):
        print(i,id)
        the_rock_friends.append(id)
# Out:
# 0 30959290
# 1 30354991
# 2 68577152
# 3 18194219
# 4 20029472
# 5 606806109
# 6 1038111553164390400
# 7 224836446
# 8 72610934
# 9 18173624
# 10 3247562564
# 11 19551156
# 12 955829659027099648
# 13 111199728
# 14 21681559
# 15 169686021
# 16 3908301134
# 17 33261208
# 18 47529622
# 19 939091
# 20 24544452
# 21 612975060
# 22 813286
# 23 1401135751
# 24 23019705
# 25 232595517
# 26 30272162
# 27 1024336429198049280
# 28 11347122
# 29 38349184

# %%
api.get_user(the_rock_friends[0]).screen_name
# Out:
# 'spiceadams'

# %% [markdown]
# # SEARCH TWEETS

# %%
#First way
query = 'django'
api.search(q=query)
# Out:
# [Status(_api=<tweepy.api.API object at 0x0000025AECC47160>, _json={'created_at': 'Wed Oct 07 12:53:30 +0000 2020', 'id': 1313824773802127365, 'id_str': '1313824773802127365', 'text': 'https://t.co/XhKmnWtqtC', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1313824770895478785, 'id_str': '1313824770895478785', 'indices': [0, 23], 'media_url': 'http://pbs.twimg.com/media/Ejukqw5VgAERMKS.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Ejukqw5VgAERMKS.jpg', 'url': 'https://t.co/XhKmnWtqtC', 'display_url': 'pic.twitter.com/XhKmnWtqtC', 'expanded_url': 'https://twitter.com/ruk_django/status/1313824773802127365/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}, 'large': {'w': 2048, 'h': 1152, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1313824770895478785, 'id_str': '1313824770895478785', 'indices': [0, 23], 'media_url': 'http://pbs.twimg.com/media/Ejukqw5VgAERMKS.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Ejukqw5VgAERMKS.jpg', 'url': 'https://t.co/XhKmnWtqtC', 'display_url': 'pic.twitter.com/XhKmnWtqtC', 'expanded_url': 'https://twitter.com/ruk_django/status/1313824773802127365/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}, 'large': {'w': 2048, 'h': 1152, 'resize': 'fit'}}}]}, 'metadata': {'iso_language_code': 'und', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 167298848, 'id_str': '167298848', 'name': 'るく', 'screen_name': 'ruk_django', 'location': '修羅の国', 'description': 'タイヨー信者', 'url': 'https://t.co/tF4LAL0GI8', 'entities': {'url': {'urls': [{'url': 'https://t.co/tF4LAL0GI8', 'expanded_url': 'http://com.nicovideo.jp/community/co1704928', 'display_url': 'com.nicovideo.jp/community/co17…', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 573, 'friends_count': 434, 'listed_count': 17, 'created_at': 'Fri Jul 16 06:34:24 +0000 2010', 'favourites_count': 4718, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 43089, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/582490523652337664/MhLY3UNg_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/582490523652337664/MhLY3UNg_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/167298848/1523895998', 'profile_link_color': '36AAF7', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'und'}, created_at=datetime.datetime(2020, 10, 7, 12, 53, 30), id=1313824773802127365, id_str='1313824773802127365', text='https://t.co/XhKmnWtqtC', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_menti ...
#  Status(_api=<tweepy.api.API object at 0x0000025AECC47160>, _json={'created_at': 'Wed Oct 07 12:52:51 +0000 2020', 'id': 1313824612078120961, 'id_str': '1313824612078120961', 'text': 'キーリの作者の作品がアニメ化と実写化かあ。\nキーリ好きだった', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 386432168, 'id_str': '386432168', 'name': 'ジャンゴ・コバーン', 'screen_name': 'Django_Coburn', 'location': '地獄の入り口', 'description': '人生は続いていく。終わりはない。俺の人生に必要なのは、きっかけだ。自分の殻に閉じこもって生きるべきじゃない。俺は人並みの人間になれるはずだ。\nギター/プロレス/映画/音楽/田端大学ってなんだよ', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 860, 'friends_count': 483, 'listed_count': 24, 'created_at': 'Fri Oct 07 08:39:36 +0000 2011', 'favourites_count': 83777, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 14022, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1229442872816132096/09qhuy0X_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1229442872816132096/09qhuy0X_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/386432168/1598235700', 'profile_link_color': 'ABB8C2', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'ja'}, created_at=datetime.datetime(2020, 10, 7, 12, 52, 51), id=1313824612078120961, id_str='1313824612078120961', text='キーリの作者の作品がアニメ化と実写化かあ。\nキーリ好きだった', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, metadata={'iso_language_code': 'ja', 'result_type': 'recent'}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x0000025AECC47160>, _json={'id': 386432168, 'id_str': '386432168', 'name': 'ジャンゴ・コバーン', 'screen_name': 'Django_Coburn', 'location': '地獄の入り口', 'description': '人生は続いていく。終わりはない。俺の人生に必要なのは、きっかけだ。自分の殻に閉じこもって生きるべきじゃない。俺は人並みの人間になれるはずだ。\nギター/プロレス/映画/音楽/田端大学ってなんだよ', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 860, 'friends_count': 483, 'listed_count': 24, 'created_at': 'Fri Oct 07 08:39:36 +0000 2011', 'favourites_count': 83777, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 14022, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1229442872816132096/09qhuy0X_normal.jpg', 'profile_image ...
#  Status(_api=<tweepy.api.API object at 0x0000025AECC47160>, _json={'created_at': 'Wed Oct 07 12:52:48 +0000 2020', 'id': 1313824596915675137, 'id_str': '1313824596915675137', 'text': '@Quentin_DJANGO Who can resist loving him 😍😂 https://t.co/GtzRG85zQ7', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Quentin_DJANGO', 'name': 'Cliff Booth', 'id': 493213714, 'id_str': '493213714', 'indices': [0, 15]}], 'urls': [], 'media': [{'id': 1313824585259778054, 'id_str': '1313824585259778054', 'indices': [45, 68], 'media_url': 'http://pbs.twimg.com/tweet_video_thumb/Ejukf9WVgAYuRdq.jpg', 'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/Ejukf9WVgAYuRdq.jpg', 'url': 'https://t.co/GtzRG85zQ7', 'display_url': 'pic.twitter.com/GtzRG85zQ7', 'expanded_url': 'https://twitter.com/WhoDebi/status/1313824596915675137/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 498, 'h': 212, 'resize': 'fit'}, 'large': {'w': 498, 'h': 212, 'resize': 'fit'}, 'small': {'w': 498, 'h': 212, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1313824585259778054, 'id_str': '1313824585259778054', 'indices': [45, 68], 'media_url': 'http://pbs.twimg.com/tweet_video_thumb/Ejukf9WVgAYuRdq.jpg', 'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/Ejukf9WVgAYuRdq.jpg', 'url': 'https://t.co/GtzRG85zQ7', 'display_url': 'pic.twitter.com/GtzRG85zQ7', 'expanded_url': 'https://twitter.com/WhoDebi/status/1313824596915675137/photo/1', 'type': 'animated_gif', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 498, 'h': 212, 'resize': 'fit'}, 'large': {'w': 498, 'h': 212, 'resize': 'fit'}, 'small': {'w': 498, 'h': 212, 'resize': 'fit'}}, 'video_info': {'aspect_ratio': [249, 106], 'variants': [{'bitrate': 0, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/tweet_video/Ejukf9WVgAYuRdq.mp4'}]}}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': 1313822829687656448, 'in_reply_to_status_id_str': '1313822829687656448', 'in_reply_to_user_id': 493213714, 'in_reply_to_user_id_str': '493213714', 'in_reply_to_screen_name': 'Quentin_DJANGO', 'user': {'id': 297955449, 'id_str': '297955449', 'name': 'Debi', 'screen_name': 'WhoDebi', 'location': 'Kolkata India', 'description': 'Movie Buff. Opinionated.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1372, 'friends_count': 451, 'listed_count': 5, 'created_at': 'Fri May 13 12:18:29 +0000 2011', 'favourites_count': 52061, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 51545, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1300435186727841794/t9zgbfht_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1300435186727841794/t9zgbfht_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/297955449/1594231906', 'profile_link_color': 'FF691F', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive ...
#  Status(_api=<tweepy.api.API object at 0x0000025AECC47160>, _json={'created_at': 'Wed Oct 07 12:52:20 +0000 2020', 'id': 1313824480003645442, 'id_str': '1313824480003645442', 'text': 'RT @kabe_yuka: TVアニメ放送決定🏐2021年1月よりフジテレビ"ノイタミナ"ほかにて\n\nシリーズ最新作『2.43\u3000清陰高校男子バレー部\u3000next 4years』\nプロローグ～第一話公開中！\nまもなく第二話連載スタート予定です！\n\n【第一話日替わり予告 再掲中】…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'kabe_yuka', 'name': '壁井ユカコ', 'id': 130446710, 'id_str': '130446710', 'indices': [3, 13]}], 'urls': []}, 'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 386432168, 'id_str': '386432168', 'name': 'ジャンゴ・コバーン', 'screen_name': 'Django_Coburn', 'location': '地獄の入り口', 'description': '人生は続いていく。終わりはない。俺の人生に必要なのは、きっかけだ。自分の殻に閉じこもって生きるべきじゃない。俺は人並みの人間になれるはずだ。\nギター/プロレス/映画/音楽/田端大学ってなんだよ', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 860, 'friends_count': 483, 'listed_count': 24, 'created_at': 'Fri Oct 07 08:39:36 +0000 2011', 'favourites_count': 83777, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 14022, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1229442872816132096/09qhuy0X_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1229442872816132096/09qhuy0X_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/386432168/1598235700', 'profile_link_color': 'ABB8C2', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Oct 07 10:45:53 +0000 2020', 'id': 1313792657580122112, 'id_str': '1313792657580122112', 'text': 'TVアニメ放送決定🏐2021年1月よりフジテレビ"ノイタミナ"ほかにて\n\nシリーズ最新作『2.43\u3000清陰高校男子バレー部\u3000next 4years』\nプロローグ～第一話公開中！\nまもなく第二話連載スタート予定です！\n\n【第一話日替わ… https://t.co/DHv2R2Vs3v', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/DHv2R2Vs3v', 'expanded_url': 'https://twitter.com/i/web/status/1313792657580122112', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 130446710, 'id_str': '130446710', 'name': '壁井ユカコ', 'screen_name': 'kabe_yuka', 'location': '', 'description': '小説家です。犬派です。シリーズ刊行中『2.43 清陰高校男子バレー部』集英社（https://t.co/D58IEWi96v）。まとまった仕事情報はブログに。GoRAの1/7。 著作のご感想いただけると嬉しいです！', 'url': 'https://t.co/Lq0L1C1xDP', 'entities': {'url': {'urls': [{'url': 'https://t.co/Lq0L1C1xDP', 'expanded_url': 'http://kabeyuka.dandelion.lolipop.jp/', 'display_url': 'kabeyuka.dandelion.lolipop.jp', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/D58IEWi96v', 'expanded_url': 'http://243.shueisha.co.jp', 'display_url': '243.shueisha.co.jp', 'indices': ...
#  Status(_api=<tweepy.api.API object at 0x0000025AECC47160>, _json={'created_at': 'Wed Oct 07 12:52:16 +0000 2020', 'id': 1313824462777667585, 'id_str': '1313824462777667585', 'text': 'RT @kabe_yuka: 【お知らせ】\n「2.43」のアニメ化と並んでもう1つ映像化が動いてます！\n\nホリプロ60周年記念映画として拙著『NO CALL NO LIFE』（角川文庫刊）が映画化されます。ありがとうございます！🎊\nほ、ホリプロ！！…60周年記念！！\n\nＷ主演…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'kabe_yuka', 'name': '壁井ユカコ', 'id': 130446710, 'id_str': '130446710', 'indices': [3, 13]}], 'urls': []}, 'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 386432168, 'id_str': '386432168', 'name': 'ジャンゴ・コバーン', 'screen_name': 'Django_Coburn', 'location': '地獄の入り口', 'description': '人生は続いていく。終わりはない。俺の人生に必要なのは、きっかけだ。自分の殻に閉じこもって生きるべきじゃない。俺は人並みの人間になれるはずだ。\nギター/プロレス/映画/音楽/田端大学ってなんだよ', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 860, 'friends_count': 483, 'listed_count': 24, 'created_at': 'Fri Oct 07 08:39:36 +0000 2011', 'favourites_count': 83777, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 14022, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1229442872816132096/09qhuy0X_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1229442872816132096/09qhuy0X_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/386432168/1598235700', 'profile_link_color': 'ABB8C2', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Oct 07 10:13:52 +0000 2020', 'id': 1313784602083819520, 'id_str': '1313784602083819520', 'text': '【お知らせ】\n「2.43」のアニメ化と並んでもう1つ映像化が動いてます！\n\nホリプロ60周年記念映画として拙著『NO CALL NO LIFE』（角川文庫刊）が映画化されます。ありがとうございます！🎊\nほ、ホリプロ！！…60周年記… https://t.co/5ZYWycUIpy', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/5ZYWycUIpy', 'expanded_url': 'https://twitter.com/i/web/status/1313784602083819520', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 130446710, 'id_str': '130446710', 'name': '壁井ユカコ', 'screen_name': 'kabe_yuka', 'location': '', 'description': '小説家です。犬派です。シリーズ刊行中『2.43 清陰高校男子バレー部』集英社（https://t.co/D58IEWi96v）。まとまった仕事情報はブログに。GoRAの1/7。 著作のご感想いただけると嬉しいです！', 'url': 'https://t.co/Lq0L1C1xDP', 'entities': {'url': {'urls': [{'url': 'https://t.co/Lq0L1C1xDP', 'expanded_url': 'http://kabeyuka.dandelion.lolipop.jp/', 'display_url': 'kabeyuka.dandelion.lolipop.jp', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/D58IEWi96v', 'expanded_url': 'http://243.shueisha.co.jp', 'display_url': '243.shueisha.co.jp', 'indices': [39, 62]}]}}, 'protec ...
#  Status(_api=<tweepy.api.API object at 0x0000025AECC47160>, _json={'created_at': 'Wed Oct 07 12:52:06 +0000 2020', 'id': 1313824423904935937, 'id_str': '1313824423904935937', 'text': 'RT @LunaV_10: You give them a RAP album they say "Trash, no BANGERS" \n\nYou give them an album spoiled with bangers they say "trash, what ha…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'LunaV_10', 'name': "LunA' Vee", 'id': 3707652627, 'id_str': '3707652627', 'indices': [3, 12]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 885802788130877440, 'id_str': '885802788130877440', 'name': 'Smurts', 'screen_name': 'Smurts_Django', 'location': 'Earth ', 'description': "dont take compliments as flirting, Uzo'lemala", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 3510, 'friends_count': 3980, 'listed_count': 1, 'created_at': 'Fri Jul 14 10:06:56 +0000 2017', 'favourites_count': 31070, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 13022, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1297318819866845185/1tRWt-8l_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1297318819866845185/1tRWt-8l_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/885802788130877440/1586687721', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Oct 07 11:08:37 +0000 2020', 'id': 1313798380842344455, 'id_str': '1313798380842344455', 'text': 'You give them a RAP album they say "Trash, no BANGERS" \n\nYou give them an album spoiled with bangers they say "tras… https://t.co/iPlw8F2kMy', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/iPlw8F2kMy', 'expanded_url': 'https://twitter.com/i/web/status/1313798380842344455', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3707652627, 'id_str': '3707652627', 'name': "LunA' Vee", 'screen_name': 'LunaV_10', 'location': 'Johannesburg, South Africa', 'description': "ITS NOT THAT DEEP RAMBO| These jokes ain't for the faint hearted| I Learn and unlearn EVERYDAY| South African Hip Hop Artist |  bookinglunaticvenom@gmail.com", 'url': 'https://t.co/OrCFb9rDIX', 'entities': {'url': {'urls': [{'url': 'https://t.co/OrCFb9rDIX', 'expanded_url': 'https://audiomack.com/album/lunatic-venom/cant-be-rated-1', 'display_url': 'audiomack.com/album/lunatic-…', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 3249, 'friends_count': 3049, 'listed_count': 4, 'created_at': 'Sat Sep 19 14:02:26 +0000 2015', 'fav ...
#  Status(_api=<tweepy.api.API object at 0x0000025AECC47160>, _json={'created_at': 'Wed Oct 07 12:52:05 +0000 2020', 'id': 1313824416304783360, 'id_str': '1313824416304783360', 'text': 'RT @kabe_yuka: 原作者コメント載せていただいてます。\n単行本が14年前、文庫が11年前……なんですが今も反響をくださったりずっと心にとどめてくださっている読者の方々に感謝しています😌 https://t.co/kgaQ8klOXJ', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'kabe_yuka', 'name': '壁井ユカコ', 'id': 130446710, 'id_str': '130446710', 'indices': [3, 13]}], 'urls': [{'url': 'https://t.co/kgaQ8klOXJ', 'expanded_url': 'https://twitter.com/eiga_natalie/status/1313657816687599616', 'display_url': 'twitter.com/eiga_natalie/s…', 'indices': [99, 122]}]}, 'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 386432168, 'id_str': '386432168', 'name': 'ジャンゴ・コバーン', 'screen_name': 'Django_Coburn', 'location': '地獄の入り口', 'description': '人生は続いていく。終わりはない。俺の人生に必要なのは、きっかけだ。自分の殻に閉じこもって生きるべきじゃない。俺は人並みの人間になれるはずだ。\nギター/プロレス/映画/音楽/田端大学ってなんだよ', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 860, 'friends_count': 483, 'listed_count': 24, 'created_at': 'Fri Oct 07 08:39:36 +0000 2011', 'favourites_count': 83777, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 14022, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1229442872816132096/09qhuy0X_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1229442872816132096/09qhuy0X_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/386432168/1598235700', 'profile_link_color': 'ABB8C2', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Oct 07 12:36:41 +0000 2020', 'id': 1313820542189797376, 'id_str': '1313820542189797376', 'text': '原作者コメント載せていただいてます。\n単行本が14年前、文庫が11年前……なんですが今も反響をくださったりずっと心にとどめてくださっている読者の方々に感謝しています😌 https://t.co/kgaQ8klOXJ', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/kgaQ8klOXJ', 'expanded_url': 'https://twitter.com/eiga_natalie/status/1313657816687599616', 'display_url': 'twitter.com/eiga_natalie/s…', 'indices': [84, 107]}]}, 'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 130446710, 'id_str': '130446710', 'name': '壁井ユカコ', 'screen_name': 'kabe_yuka', 'location': '', 'description': '小説家です。犬派です。シリーズ刊行中『2.43 清陰高校男子バレー部』集英社（https://t.co/D58IEWi96v）。まとまった仕事情報はブログに。GoRAの1/7。 著作のご感想いただけると嬉しいです！', 'url': 'https://t.co/Lq0L1C1xDP', 'entities': {'url': {'urls': [{'url': 'https://t.co/Lq0L1C1xDP', 'expanded_url': 'http://kabeyuka.dandelion.lolipop.jp/', 'display_url': 'kabeyuka.dandelion.lolipop.jp', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t. ...
#  Status(_api=<tweepy.api.API object at 0x0000025AECC47160>, _json={'created_at': 'Wed Oct 07 12:51:59 +0000 2020', 'id': 1313824390585307136, 'id_str': '1313824390585307136', 'text': 'フロントエンド htmlcssjs\nバックエンド Django\nでなにか作りたい', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 982226739387449344, 'id_str': '982226739387449344', 'name': 'こっぷ', 'screen_name': 'butsuli_shine', 'location': '', 'description': '群馬高専3J/Python/', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 443, 'friends_count': 595, 'listed_count': 2, 'created_at': 'Fri Apr 06 12:01:18 +0000 2018', 'favourites_count': 40412, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 22678, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1307176835814322176/XmUBljP8_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1307176835814322176/XmUBljP8_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/982226739387449344/1600413571', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'ja'}, created_at=datetime.datetime(2020, 10, 7, 12, 51, 59), id=1313824390585307136, id_str='1313824390585307136', text='フロントエンド htmlcssjs\nバックエンド Django\nでなにか作りたい', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, metadata={'iso_language_code': 'ja', 'result_type': 'recent'}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x0000025AECC47160>, _json={'id': 982226739387449344, 'id_str': '982226739387449344', 'name': 'こっぷ', 'screen_name': 'butsuli_shine', 'location': '', 'description': '群馬高専3J/Python/', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 443, 'friends_count': 595, 'listed_count': 2, 'created_at': 'Fri Apr 06 12:01:18 +0000 2018', 'favourites_count': 40412, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 22678, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1307176835814322176/XmUBljP8_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1307176835814322176/XmUBljP8_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/982226739387449344/1600413571', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color ...
#  Status(_api=<tweepy.api.API object at 0x0000025AECC47160>, _json={'created_at': 'Wed Oct 07 12:51:29 +0000 2020', 'id': 1313824265712484352, 'id_str': '1313824265712484352', 'text': 'https://t.co/4Y0Yp96Oi4', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1313824261593677825, 'id_str': '1313824261593677825', 'indices': [0, 23], 'media_url': 'http://pbs.twimg.com/media/EjukNHmUwAEMDUm.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EjukNHmUwAEMDUm.jpg', 'url': 'https://t.co/4Y0Yp96Oi4', 'display_url': 'pic.twitter.com/4Y0Yp96Oi4', 'expanded_url': 'https://twitter.com/ruk_django/status/1313824265712484352/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}, 'large': {'w': 2048, 'h': 1152, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1313824261593677825, 'id_str': '1313824261593677825', 'indices': [0, 23], 'media_url': 'http://pbs.twimg.com/media/EjukNHmUwAEMDUm.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EjukNHmUwAEMDUm.jpg', 'url': 'https://t.co/4Y0Yp96Oi4', 'display_url': 'pic.twitter.com/4Y0Yp96Oi4', 'expanded_url': 'https://twitter.com/ruk_django/status/1313824265712484352/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}, 'large': {'w': 2048, 'h': 1152, 'resize': 'fit'}}}]}, 'metadata': {'iso_language_code': 'und', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 167298848, 'id_str': '167298848', 'name': 'るく', 'screen_name': 'ruk_django', 'location': '修羅の国', 'description': 'タイヨー信者', 'url': 'https://t.co/tF4LAL0GI8', 'entities': {'url': {'urls': [{'url': 'https://t.co/tF4LAL0GI8', 'expanded_url': 'http://com.nicovideo.jp/community/co1704928', 'display_url': 'com.nicovideo.jp/community/co17…', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 573, 'friends_count': 434, 'listed_count': 17, 'created_at': 'Fri Jul 16 06:34:24 +0000 2010', 'favourites_count': 4718, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 43089, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/582490523652337664/MhLY3UNg_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/582490523652337664/MhLY3UNg_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/167298848/1523895998', 'profile_link_color': '36AAF7', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'und'}, created_at=datetime.datetime(2020, 10, 7, 12, 51, 29), id=1313824265712484352, id_str='1313824265712484352', text='https://t.co/4Y0Yp96Oi4', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_menti ...
#  Status(_api=<tweepy.api.API object at 0x0000025AECC47160>, _json={'created_at': 'Wed Oct 07 12:51:18 +0000 2020', 'id': 1313824222284742660, 'id_str': '1313824222284742660', 'text': '@Django__go 😂', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Django__go', 'name': 'Django__go   🐝', 'id': 3794478437, 'id_str': '3794478437', 'indices': [0, 11]}], 'urls': []}, 'metadata': {'iso_language_code': 'und', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': 1313823834311622661, 'in_reply_to_status_id_str': '1313823834311622661', 'in_reply_to_user_id': 3794478437, 'in_reply_to_user_id_str': '3794478437', 'in_reply_to_screen_name': 'Django__go', 'user': {'id': 1130893815156486153, 'id_str': '1130893815156486153', 'name': 'Claudia 🏳️\u200d⚧️🏳️\u200d🌈', 'screen_name': 'leaddagan', 'location': 'Everywhere at Once', 'description': 'Tweete à tiers-temps.', 'url': 'https://t.co/vUhc2101JL', 'entities': {'url': {'urls': [{'url': 'https://t.co/vUhc2101JL', 'expanded_url': 'https://defendtheweb.net', 'display_url': 'defendtheweb.net', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 440, 'friends_count': 388, 'listed_count': 4, 'created_at': 'Tue May 21 17:51:11 +0000 2019', 'favourites_count': 30359, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 21585, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1288080817982509057/3TQmJuGH_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1288080817982509057/3TQmJuGH_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1130893815156486153/1593039997', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'und'}, created_at=datetime.datetime(2020, 10, 7, 12, 51, 18), id=1313824222284742660, id_str='1313824222284742660', text='@Django__go 😂', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Django__go', 'name': 'Django__go   🐝', 'id': 3794478437, 'id_str': '3794478437', 'indices': [0, 11]}], 'urls': []}, metadata={'iso_language_code': 'und', 'result_type': 'recent'}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=1313823834311622661, in_reply_to_status_id_str='1313823834311622661', in_reply_to_user_id=3794478437, in_reply_to_user_id_str='3794478437', in_reply_to_screen_name='Django__go', author=User(_api=<tweepy.api.API object at 0x0000025AECC47160>, _json={'id': 1130893815156486153, 'id_str': '1130893815156486153', 'name': 'Claudia 🏳️\u200d⚧️🏳️\u200d🌈', 'screen_name': 'leaddagan', 'location': 'Everywhere at Once', 'description': 'Tweete à tiers-temps.', 'url': 'https://t.co/vUhc2101JL', 'entities': {'url': {'urls': [{'url': 'https://t.co/vUhc2101JL', 'expanded_url': 'https://defendtheweb.net', 'display_url': 'defendtheweb.net', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 440, 'friends_count': 388, 'listed_count': 4, 'created_at': 'Tue May 21 17:51:11 +0000 2019', 'favourites_count': 30359, 'utc_offset': None, 'time_zone': None, 'geo_enabled':  ...
#  Status(_api=<tweepy.api.API object at 0x0000025AECC47160>, _json={'created_at': 'Wed Oct 07 12:51:00 +0000 2020', 'id': 1313824145264775170, 'id_str': '1313824145264775170', 'text': 'RT @couponfree01: Udemy Free Discount - WebSockets Mastery - Beginner to Advanced #udemycoupon https://t.co/CtHWO9ewA8\n\n#webdevelopment #ja…', 'truncated': False, 'entities': {'hashtags': [{'text': 'udemycoupon', 'indices': [82, 94]}, {'text': 'webdevelopment', 'indices': [120, 135]}], 'symbols': [], 'user_mentions': [{'screen_name': 'couponfree01', 'name': 'Coupon Free', 'id': 970572251090186240, 'id_str': '970572251090186240', 'indices': [3, 16]}], 'urls': [{'url': 'https://t.co/CtHWO9ewA8', 'expanded_url': 'http://www.couponfree.uk/2019/12/websockets-mastery-beginner-to-advanced.html', 'display_url': 'couponfree.uk/2019/12/websoc…', 'indices': [95, 118]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://cancanit.com" rel="nofollow">DCHelper</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 925683142312235008, 'id_str': '925683142312235008', 'name': 'David Cottila', 'screen_name': 'cottila', 'location': 'Tallinn, Estonia', 'description': 'Hiking fan and #softwareengineer in a little part.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 4513, 'friends_count': 454, 'listed_count': 86, 'created_at': 'Wed Nov 01 11:17:14 +0000 2017', 'favourites_count': 20590, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 53332, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/927388567520849920/GyKz1Ae-_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/927388567520849920/GyKz1Ae-_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Oct 07 12:40:00 +0000 2020', 'id': 1313821375552016384, 'id_str': '1313821375552016384', 'text': 'Udemy Free Discount - WebSockets Mastery - Beginner to Advanced #udemycoupon https://t.co/CtHWO9ewA8… https://t.co/vFKfgUKS8e', 'truncated': True, 'entities': {'hashtags': [{'text': 'udemycoupon', 'indices': [64, 76]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/CtHWO9ewA8', 'expanded_url': 'http://www.couponfree.uk/2019/12/websockets-mastery-beginner-to-advanced.html', 'display_url': 'couponfree.uk/2019/12/websoc…', 'indices': [77, 100]}, {'url': 'https://t.co/vFKfgUKS8e', 'expanded_url': 'https://twitter.com/i/web/status/1313821375552016384', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [102, 125]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 970572251090186240, 'id_str': '970572251090186240', 'name': 'Coupon Free', 'screen_name': 'couponfree01', 'location': 'Dallas, NC', 'description': 'Visit https://t.co/KlWHEisgbp  for 100% free coupon codes from #Udemy. Updated hourly so we always have the freshest coupons. #U ...
#  Status(_api=<tweepy.api.API object at 0x0000025AECC47160>, _json={'created_at': 'Wed Oct 07 12:50:46 +0000 2020', 'id': 1313824087030943744, 'id_str': '1313824087030943744', 'text': '@Django_3581 知らないからこれからめっちゃ見てますね^_^\nそして気が向いたら僕の5万円を増やしてください！！', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Django_3581', 'name': 'SAT(´･ω･`)', 'id': 1244650282945933312, 'id_str': '1244650282945933312', 'indices': [0, 12]}], 'urls': []}, 'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1313785678161801216, 'in_reply_to_status_id_str': '1313785678161801216', 'in_reply_to_user_id': 1244650282945933312, 'in_reply_to_user_id_str': '1244650282945933312', 'in_reply_to_screen_name': 'Django_3581', 'user': {'id': 933794874742120448, 'id_str': '933794874742120448', 'name': 'てるたろう', 'screen_name': 'cGha7C5gNWtpbpN', 'location': '大阪 ', 'description': 'この先10年かけて後ろをむかないようにするよ！', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 45, 'friends_count': 196, 'listed_count': 0, 'created_at': 'Thu Nov 23 20:30:22 +0000 2017', 'favourites_count': 57, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 105, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1235426292926803969/aHvF2TYh_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1235426292926803969/aHvF2TYh_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/933794874742120448/1570214292', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'ja'}, created_at=datetime.datetime(2020, 10, 7, 12, 50, 46), id=1313824087030943744, id_str='1313824087030943744', text='@Django_3581 知らないからこれからめっちゃ見てますね^_^\nそして気が向いたら僕の5万円を増やしてください！！', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Django_3581', 'name': 'SAT(´･ω･`)', 'id': 1244650282945933312, 'id_str': '1244650282945933312', 'indices': [0, 12]}], 'urls': []}, metadata={'iso_language_code': 'ja', 'result_type': 'recent'}, source='Twitter for iPhone', source_url='http://twitter.com/download/iphone', in_reply_to_status_id=1313785678161801216, in_reply_to_status_id_str='1313785678161801216', in_reply_to_user_id=1244650282945933312, in_reply_to_user_id_str='1244650282945933312', in_reply_to_screen_name='Django_3581', author=User(_api=<tweepy.api.API object at 0x0000025AECC47160>, _json={'id': 933794874742120448, 'id_str': '933794874742120448', 'name': 'てるたろう', 'screen_name': 'cGha7C5gNWtpbpN', 'location': '大阪 ', 'description': 'この先10年かけて後ろをむかないようにするよ！', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 45, 'friends_count': 196, 'listed_count': 0, 'created_at': 'Thu Nov 23 20:30:22 +0000 2017', 'favourites_count': 57, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 105, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_ba ...
#  Status(_api=<tweepy.api.API object at 0x0000025AECC47160>, _json={'created_at': 'Wed Oct 07 12:49:46 +0000 2020', 'id': 1313823834311622661, 'id_str': '1313823834311622661', 'text': '@leaddagan Ok désolé ☹️', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'leaddagan', 'name': 'Claudia 🏳️\u200d⚧️🏳️\u200d🌈', 'id': 1130893815156486153, 'id_str': '1130893815156486153', 'indices': [0, 10]}], 'urls': []}, 'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', 'in_reply_to_status_id': 1313823465322024962, 'in_reply_to_status_id_str': '1313823465322024962', 'in_reply_to_user_id': 1130893815156486153, 'in_reply_to_user_id_str': '1130893815156486153', 'in_reply_to_screen_name': 'leaddagan', 'user': {'id': 3794478437, 'id_str': '3794478437', 'name': 'Django__go   🐝', 'screen_name': 'Django__go', 'location': '', 'description': 'RAB', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 455, 'friends_count': 353, 'listed_count': 18, 'created_at': 'Sun Sep 27 16:15:36 +0000 2015', 'favourites_count': 21552, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 30335, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/648223116863401984/yq1IWqPG_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/648223116863401984/yq1IWqPG_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3794478437/1594099359', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 1, 'favorited': False, 'retweeted': False, 'lang': 'fr'}, created_at=datetime.datetime(2020, 10, 7, 12, 49, 46), id=1313823834311622661, id_str='1313823834311622661', text='@leaddagan Ok désolé ☹️', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'leaddagan', 'name': 'Claudia 🏳️\u200d⚧️🏳️\u200d🌈', 'id': 1130893815156486153, 'id_str': '1130893815156486153', 'indices': [0, 10]}], 'urls': []}, metadata={'iso_language_code': 'fr', 'result_type': 'recent'}, source='Twitter for iPad', source_url='http://twitter.com/#!/download/ipad', in_reply_to_status_id=1313823465322024962, in_reply_to_status_id_str='1313823465322024962', in_reply_to_user_id=1130893815156486153, in_reply_to_user_id_str='1130893815156486153', in_reply_to_screen_name='leaddagan', author=User(_api=<tweepy.api.API object at 0x0000025AECC47160>, _json={'id': 3794478437, 'id_str': '3794478437', 'name': 'Django__go   🐝', 'screen_name': 'Django__go', 'location': '', 'description': 'RAB', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 455, 'friends_count': 353, 'listed_count': 18, 'created_at': 'Sun Sep 27 16:15:36 +0000 2015', 'favourites_count': 21552, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 30335, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/ ...
#  Status(_api=<tweepy.api.API object at 0x0000025AECC47160>, _json={'created_at': 'Wed Oct 07 12:49:14 +0000 2020', 'id': 1313823699032825856, 'id_str': '1313823699032825856', 'text': 'RT @couponfree01: Udemy Free Discount - WebSockets Mastery - Beginner to Advanced #udemycoupon https://t.co/CtHWO9ewA8\n\n#webdevelopment #ja…', 'truncated': False, 'entities': {'hashtags': [{'text': 'udemycoupon', 'indices': [82, 94]}, {'text': 'webdevelopment', 'indices': [120, 135]}], 'symbols': [], 'user_mentions': [{'screen_name': 'couponfree01', 'name': 'Coupon Free', 'id': 970572251090186240, 'id_str': '970572251090186240', 'indices': [3, 16]}], 'urls': [{'url': 'https://t.co/CtHWO9ewA8', 'expanded_url': 'http://www.couponfree.uk/2019/12/websockets-mastery-beginner-to-advanced.html', 'display_url': 'couponfree.uk/2019/12/websoc…', 'indices': [95, 118]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://rishabhmishra.me/" rel="nofollow">React Dev autobot</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 812555214024740865, 'id_str': '812555214024740865', 'name': 'React Developer', 'screen_name': '_reactdev', 'location': 'Everywhere', 'description': 'React, Redux and React-Native Developer', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 6433, 'friends_count': 90, 'listed_count': 139, 'created_at': 'Sat Dec 24 07:07:14 +0000 2016', 'favourites_count': 137, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 210311, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/812556678344351744/SiRnLTqx_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/812556678344351744/SiRnLTqx_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Oct 07 12:40:00 +0000 2020', 'id': 1313821375552016384, 'id_str': '1313821375552016384', 'text': 'Udemy Free Discount - WebSockets Mastery - Beginner to Advanced #udemycoupon https://t.co/CtHWO9ewA8… https://t.co/vFKfgUKS8e', 'truncated': True, 'entities': {'hashtags': [{'text': 'udemycoupon', 'indices': [64, 76]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/CtHWO9ewA8', 'expanded_url': 'http://www.couponfree.uk/2019/12/websockets-mastery-beginner-to-advanced.html', 'display_url': 'couponfree.uk/2019/12/websoc…', 'indices': [77, 100]}, {'url': 'https://t.co/vFKfgUKS8e', 'expanded_url': 'https://twitter.com/i/web/status/1313821375552016384', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [102, 125]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 970572251090186240, 'id_str': '970572251090186240', 'name': 'Coupon Free', 'screen_name': 'couponfree01', 'location': 'Dallas, NC', 'description': 'Visit https://t.co/KlWHEisgbp  for 100% free coupon codes from #Udemy. Updated hourly so we always have the freshest coupons.  ...
#  Status(_api=<tweepy.api.API object at 0x0000025AECC47160>, _json={'created_at': 'Wed Oct 07 12:49:14 +0000 2020', 'id': 1313823698995085313, 'id_str': '1313823698995085313', 'text': 'RT @NewOnline23: Accelerated ES6 JavaScript Training -&gt; https://t.co/cgO2hYeM1V\n\n#100DaysOfCode #html5 #NodeJs #Angular #WordPress #react #…', 'truncated': False, 'entities': {'hashtags': [{'text': '100DaysOfCode', 'indices': [84, 98]}, {'text': 'html5', 'indices': [99, 105]}, {'text': 'NodeJs', 'indices': [106, 113]}, {'text': 'Angular', 'indices': [114, 122]}, {'text': 'WordPress', 'indices': [123, 133]}, {'text': 'react', 'indices': [134, 140]}], 'symbols': [], 'user_mentions': [{'screen_name': 'NewOnline23', 'name': 'New Online Courses', 'id': 1185467885713416192, 'id_str': '1185467885713416192', 'indices': [3, 15]}], 'urls': [{'url': 'https://t.co/cgO2hYeM1V', 'expanded_url': 'https://bit.ly/336gKft', 'display_url': 'bit.ly/336gKft', 'indices': [59, 82]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://rishabhmishra.me/" rel="nofollow">React Dev autobot</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 812555214024740865, 'id_str': '812555214024740865', 'name': 'React Developer', 'screen_name': '_reactdev', 'location': 'Everywhere', 'description': 'React, Redux and React-Native Developer', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 6433, 'friends_count': 90, 'listed_count': 139, 'created_at': 'Sat Dec 24 07:07:14 +0000 2016', 'favourites_count': 137, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 210311, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/812556678344351744/SiRnLTqx_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/812556678344351744/SiRnLTqx_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Oct 07 10:40:00 +0000 2020', 'id': 1313791176835764226, 'id_str': '1313791176835764226', 'text': 'Accelerated ES6 JavaScript Training -&gt; https://t.co/cgO2hYeM1V\n\n#100DaysOfCode #html5 #NodeJs #Angular #WordPress… https://t.co/qOVHLupc8v', 'truncated': True, 'entities': {'hashtags': [{'text': '100DaysOfCode', 'indices': [67, 81]}, {'text': 'html5', 'indices': [82, 88]}, {'text': 'NodeJs', 'indices': [89, 96]}, {'text': 'Angular', 'indices': [97, 105]}, {'text': 'WordPress', 'indices': [106, 116]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/cgO2hYeM1V', 'expanded_url': 'https://bit.ly/336gKft', 'display_url': 'bit.ly/336gKft', 'indices': [42, 65]}, {'url': 'https://t.co/qOVHLupc8v', 'expanded_url': 'https://twitter.com/i/web/status/1313791176835764226', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [118, 141]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1185467885713416192, 'id_str': '1185467885713416 ...

# %%
query = '#django'
#query = '#django - jQuery -@udemy -Bootstrap -Discount'
for i, status in enumerate(tweepy.Cursor(api.search,q=query).items(50)):
    print(i,status.text,status.author.screen_name)
# Out:
# 0 RT @couponfree01: Udemy Free Discount - WebSockets Mastery - Beginner to Advanced #udemycoupon https://t.co/CtHWO9ewA8
#
# #webdevelopment #ja… cottila
# 1 RT @couponfree01: Udemy Free Discount - WebSockets Mastery - Beginner to Advanced #udemycoupon https://t.co/CtHWO9ewA8
#
# #webdevelopment #ja… _reactdev
# 2 RT @NewOnline23: Accelerated ES6 JavaScript Training -&gt; https://t.co/cgO2hYeM1V
#
# #100DaysOfCode #html5 #NodeJs #Angular #WordPress #react #… _reactdev
# 3 RT @ravishsaifi: FREE Python Training.
# Join the all-new free batch for the Core Python Classes from this Saturday Evening classes delivered… Fabriciosx
# 4 RT @ravishsaifi: FREE Python Training.
# Join the all-new free batch for the Core Python Classes from this Saturday Evening classes delivered… api_learnn
# 5 RT @NewOnline23: Accelerated ES6 JavaScript Training -&gt; https://t.co/cgO2hYeM1V
#
# #100DaysOfCode #html5 #NodeJs #Angular #WordPress #react #… JimLynchCodes
# 6 RT @couponfree01: Udemy Free Discount - WebSockets Mastery - Beginner to Advanced #udemycoupon https://t.co/CtHWO9ewA8
#
# #webdevelopment #ja… php_synopsis
# 7 RT @couponfree01: Udemy Free Discount - WebSockets Mastery - Beginner to Advanced #udemycoupon https://t.co/CtHWO9ewA8
#
# #webdevelopment #ja… Alphabe99195368
# 8 RT @couponfree01: Udemy Free Discount - WebSockets Mastery - Beginner to Advanced #udemycoupon https://t.co/CtHWO9ewA8
#
# #webdevelopment #ja… TheDeveloperBot
# 9 RT @byLilyV: #Python and #Django #FullStack #WebDeveloper
# Learn to build #websites with #HTML
# #CSS
# #Bootstrap
# #Javascript
# #jQuery
# #Python3… dailyvigour
# 10 RT @byLilyV: #Python and #Django #FullStack #WebDeveloper
# Learn to build #websites with #HTML
# #CSS
# #Bootstrap
# #Javascript
# #jQuery
# #Python3… javascript_bot_
# 11 RT @byLilyV: #Python and #Django #FullStack #WebDeveloper
# Learn to build #websites with #HTML
# #CSS
# #Bootstrap
# #Javascript
# #jQuery
# #Python3… nlognbot
# 12 RT @byLilyV: #Python and #Django #FullStack #WebDeveloper
# Learn to build #websites with #HTML
# #CSS
# #Bootstrap
# #Javascript
# #jQuery
# #Python3… _codenewbiebot
# 13 RT @byLilyV: #Python and #Django #FullStack #WebDeveloper
# Learn to build #websites with #HTML
# #CSS
# #Bootstrap
# #Javascript
# #jQuery
# #Python3… AaronCuddeback
# 14 RT @byLilyV: #Python and #Django #FullStack #WebDeveloper
# Learn to build #websites with #HTML
# #CSS
# #Bootstrap
# #Javascript
# #jQuery
# #Python3… _lane001
# 15 RT @byLilyV: #Python and #Django #FullStack #WebDeveloper
# Learn to build #websites with #HTML
# #CSS
# #Bootstrap
# #Javascript
# #jQuery
# #Python3… xaelbot
# 16 RT @byLilyV: #Python and #Django #FullStack #WebDeveloper
# Learn to build #websites with #HTML
# #CSS
# #Bootstrap
# #Javascript
# #jQuery
# #Python3… TheDeveloperBot
# 17 #Python and #Django #FullStack #WebDeveloper
# Learn to build #websites with #HTML
# #CSS
# #Bootstrap
# #Javascript… https://t.co/HqvYrpUBUS byLilyV
# 18 RT @couponfree01: Udemy Free Discount - JSON in Action: Build JSON-Based Applications #udemycoupon https://t.co/7md1Vh13AS
#
# #webdevelopment… CodingRetweets
# 19 RT @devHarison: Join us this Saturday, 10th October at 🕓 5pm EAT as we proceed on 🚀 with 👨🏾‍💻 #TDD with #django.
# In case you missed the las… PeterOkwara
# 20 RT @couponfree01: Udemy Free Discount - Learn ReactJS: Code Like A Facebook Developer #udemycoupon https://t.co/2O30PBEp96
#
# #webdevelopment… cloudnewbie
# 21 RT @couponed_code: All courses for “nodejs”
#
# https://t.co/QmDXavDNJd
#
# #CodeNewbie #node #redux #javascript30 #mysql #API #PHP #NodeJs #java… nodeQuotesBot
# 22 RT @couponed_code: All courses for “nodejs”
#
# https://t.co/QmDXavDNJd
#
# #CodeNewbie #node #redux #javascript30 #mysql #API #PHP #NodeJs #java… busuulwa_mark
# 23 RT @iampujan20: day6:
# building django single page ecommerce project from @JustinMitchel django 3 bootcamp streamed in Youtube. pushed the c… cloudnewbie
# 24 RT @iampujan20: day6:
# building django single page ecommerce project from @JustinMitchel django 3 bootcamp streamed in Youtube. pushed the c… codedailybot
# 25 RT @iampujan20: day6:
# building django single page ecommerce project from @JustinMitchel django 3 bootcamp streamed in Youtube. pushed the c… codedailybot
# 26 RT @iampujan20: day6:
# building django single page ecommerce project from @JustinMitchel django 3 bootcamp streamed in Youtube. pushed the c… codedailybot
# 27 RT @iampujan20: day6:
# building django single page ecommerce project from @JustinMitchel django 3 bootcamp streamed in Youtube. pushed the c… codedailybot
# 28 RT @iampujan20: day6:
# building django single page ecommerce project from @JustinMitchel django 3 bootcamp streamed in Youtube. pushed the c… codedailybot
# 29 RT @iampujan20: day6:
# building django single page ecommerce project from @JustinMitchel django 3 bootcamp streamed in Youtube. pushed the c… codedailybot
# 30 RT @iampujan20: day6:
# building django single page ecommerce project from @JustinMitchel django 3 bootcamp streamed in Youtube. pushed the c… Alphabe99195368
# 31 RT @iampujan20: day6:
# building django single page ecommerce project from @JustinMitchel django 3 bootcamp streamed in Youtube. pushed the c… RobotProud
# 32 RT @iampujan20: day6:
# building django single page ecommerce project from @JustinMitchel django 3 bootcamp streamed in Youtube. pushed the c… 100xcode
# 33 RT @iampujan20: day6:
# building django single page ecommerce project from @JustinMitchel django 3 bootcamp streamed in Youtube. pushed the c… nlognbot
# 34 RT @iampujan20: day6:
# building django single page ecommerce project from @JustinMitchel django 3 bootcamp streamed in Youtube. pushed the c… javascript_bot_
# 35 day6:
# building django single page ecommerce project from @JustinMitchel django 3 bootcamp streamed in Youtube. push… https://t.co/2ltVvs3AJu iampujan20
# 36 RT @kori_apoorva: FREE PYTHON TRAINING.
#
# Join the all-new free batch for the PYTHON Classes from this Saturday Evening classes delivered by… Alphabe99195368
# 37 RT @couponfree01: Udemy Free Discount - Learn ReactJS: Code Like A Facebook Developer #udemycoupon https://t.co/2O30PBEp96
#
# #webdevelopment… php_synopsis
# 38 RT @couponfree01: Udemy Free Discount - Learn ReactJS: Code Like A Facebook Developer #udemycoupon https://t.co/2O30PBEp96
#
# #webdevelopment… javascript_bot_
# 39 RT @couponfree01: Udemy Free Discount - Learn ReactJS: Code Like A Facebook Developer #udemycoupon https://t.co/2O30PBEp96
#
# #webdevelopment… nlognbot
# 40 RT @couponfree01: Udemy Free Discount - Learn ReactJS: Code Like A Facebook Developer #udemycoupon https://t.co/2O30PBEp96
#
# #webdevelopment… xaelbot
# 41 RT @couponfree01: Udemy Free Discount - Learn ReactJS: Code Like A Facebook Developer #udemycoupon https://t.co/2O30PBEp96
#
# #webdevelopment… Alphabe99195368
# 42 RT @couponfree01: Udemy Free Discount - Learn ReactJS: Code Like A Facebook Developer #udemycoupon https://t.co/2O30PBEp96
#
# #webdevelopment… TheDeveloperBot
# 43 RT @couponfree01: Udemy Free Discount - Learn ReactJS: Code Like A Facebook Developer #udemycoupon https://t.co/2O30PBEp96
#
# #webdevelopment… nodeQuotesBot
# 44 Udemy Free Discount - Learn ReactJS: Code Like A Facebook Developer #udemycoupon https://t.co/2O30PBEp96… https://t.co/GFHFl7jNF4 couponfree01
# 45 RT @ravishsaifi: FREE PYTHON TRAINING.
# Join the all-new free batch for the PYTHON Classes from this Saturday Evening classes delivered by t… TheCuriousLuke
# 46 RT @ravishsaifi: FREE PYTHON TRAINING.
# Join the all-new free batch for the PYTHON Classes from this Saturday Evening classes delivered by t… Alphabe99195368
# 47 FREE PYTHON TRAINING.
# Join the all-new free batch for the PYTHON Classes from this Saturday Evening classes deliver… https://t.co/wIbVYTPHa9 ravishsaifi
# 48 RT @ravishsaifi: FREE Python Training.
# Join the all-new free batch for the Core Python Classes from this Saturday Evening classes delivered… ineelbot
# 49 RT @ravishsaifi: FREE Python Training.
# Join the all-new free batch for the Core Python Classes from this Saturday Evening classes delivered… Alphabe99195368

# %%
query_username = 'Django'
search_results = set() #use set to avoid duplicates
#query = '#django - jQuery -@udemy -Bootstrap -Discount'
for i, user in enumerate(tweepy.Cursor(api.search_users,q=query_username).items(50)):
    #print(i, user.screen_name)
    search_results.add(user.screen_name)
    
print(list(search_results))
# Out:
# ['djangogirlsshef', 'DjangoWexler', 'djangogirlsblin', 'DjangoTricks', 'DJANGO_UU', 'DjangoBrands', 'django', 'DjangoGirlsBCN', 'djangoproject', 'DjangoCoffee', 'kazeociao', 'SleepyDjango', 'DjangoDSM', 'thedjangos', 'WonderBoySolek', 'DjangoGirlsPDX', 'yngvildr', 'DjangoGirlsSD', 'Django_gocrazy', 'djangogirls', 'VanDjangoMusic', 'djangostewart', 'tangowithdjango', 'DjangoGirlsPyUK', 'djangolinks', 'DjangoConEurope', '___bechiro', 'django_paris', 'DjangoConAU', 'DjangoTarantino']

# %%
query_username = 'TheRock'

def process_page(page_results):
    for i, user in enumerate(page_results):
        print(i,user.screen_name)

for i, page in enumerate(tweepy.Cursor(api.search_users,q=query_username,per_page=10).pages(3)):
    print(i, 'page')
    process_page(page)
# Out:
# 0 page
# 0 TheRock
# 1 therockBRA
# 2 1059therock
# 3 957therock
# 4 THEROCKOLPLAY
# 5 973therock
# 6 941therock
# 7 therockbest9
# 8 therock_spc
# 9 am1260therock
# 10 therock_wall
# 11 Therock926
# 12 SaucyFaust
# 13 695THEROCK_COM
# 14 933THEROCK
# 15 JimmyTraina
# 16 HeIsCooking
# 17 mattdavella
# 18 vosswater
# 19 theROCKDINERZA
# 1 page
# 0 TheRock
# 1 therockBRA
# 2 1059therock
# 3 957therock
# 4 THEROCKOLPLAY
# 5 973therock
# 6 941therock
# 7 therockbest9
# 8 therock_spc
# 9 am1260therock
# 10 therock_wall
# 11 Therock926
# 12 SaucyFaust
# 13 695THEROCK_COM
# 14 933THEROCK
# 15 JimmyTraina
# 16 HeIsCooking
# 17 mattdavella
# 18 vosswater
# 19 theROCKDINERZA
# 2 page
# 0 t3hr0ck
# 1 tarak_santhosh9
# 2 therock72pk
# 3 therock_lover98
# 4 nbctitangames
# 5 SevenBucksProd
# 6 ChivarlousBull
# 7 CarnelianDQ
# 8 hardik_therock
# 9 Gaurav_TheRock
# 10 therock14
# 11 athleticonatl
# 12 GRT_TheRock
# 13 spicer2therock
# 14 TeamBringsItOn
# 15 LayethTheElbow
# 16 JoshRimerPR
# 17 EthanLind
# 18 therock1982
# 19 ProjectRock
# 3 page
# 0 AJKirsch
# 1 therock0209
# 2 The_Johnson55
# 3 JoeVFox12
# 4 MikeDOnAir
# 5 therock676
# 6 ZachKrantz
# 7 _Eldi__
# 8 therock07
# 9 therock454
# 10 therock9002000
# 11 kevin_therock
# 12 pera_therock
# 13 therock0884
# 14 therock2086
# 15 therock108
# 16 THEROCK37756708
# 17 therockmorin
# 18 TheRockBryer
# 19 therock1424
